# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
data_path = os.path.abspath(os.path.dirname(os.getcwd()))

# %%
df_feature = pd.read_csv(data_path + '/data_process/SH000300_feature.csv', index_col=0)
df_feature.index = pd.to_datetime(df_feature.index)
df_feature
# Out:
#                           open       high        low      close   volume  \
# 2018-01-03 09:35:00  4091.4607  4093.8916  4088.7302  4093.8916  6618865
# 2018-01-03 09:40:00  4093.2311  4099.6546  4093.2311  4094.8706  5495859
# 2018-01-03 09:45:00  4094.6998  4098.9201  4093.4408  4098.3386  5494981
# 2018-01-03 09:50:00  4098.3777  4107.1072  4097.9205  4107.0200  5651402
# 2018-01-03 09:55:00  4107.2851  4109.7965  4106.0697  4109.6198  5614016
# ...                        ...        ...        ...        ...      ...
# 2023-05-12 14:40:00  3944.5700  3944.9700  3941.6800  3941.7400  2838726
# 2023-05-12 14:45:00  3941.6000  3941.6400  3939.2900  3939.6200  3840507
# 2023-05-12 14:50:00  3940.2000  3941.8200  3939.9200  3940.8000  3473375
# 2023-05-12 14:55:00  3940.4600  3940.8300  3938.9900  3939.0700  4319086
# 2023-05-12 15:00:00  3939.0700  3939.0700  3937.5300  3937.7600  3791260
#
#                          amount  pre_close    avg_price      twap_5  \
# 2018-01-03 09:35:00  8245812764  4087.4012  1245.804645  4087.84792
# 2018-01-03 09:40:00  7035481026  4093.8916  1280.142199  4089.73548
# 2018-01-03 09:45:00  6942272242  4094.8706  1263.384212  4092.36820
# 2018-01-03 09:50:00  7239851378  4098.3386  1281.071737  4096.30440
# 2018-01-03 09:55:00  6942255730  4107.0200  1236.593506  4100.74812
# ...                         ...        ...          ...         ...
# 2023-05-12 14:40:00  4362715136  3944.2700  1536.856722  3944.95800
# 2023-05-12 14:45:00  5333417984  3941.7400  1388.727578  3943.94000
# 2023-05-12 14:50:00  5176201216  3939.6200  1490.251187  3942.79000
# 2023-05-12 14:55:00  6106451968  3940.8000  1413.829678  3941.10000
# 2023-05-12 15:00:00  6050103296  3939.0700  1595.802793  3939.79800
#
#                           vwap_5  open_close  high_close  low_close   log_ret  \
# 2018-01-03 09:35:00  4089.042003   -0.000594    0.000000  -0.001261  0.001587
# 2018-01-03 09:40:00  4090.896409   -0.000400    0.001168  -0.000400  0.000239
# 2018-01-03 09:45:00  4093.200774   -0.000888    0.000142  -0.001195  0.000847
# 2018-01-03 09:50:00  4096.814928   -0.002104    0.000021  -0.002216  0.002116
# 2018-01-03 09:55:00  4100.551619   -0.000568    0.000043  -0.000864  0.000633
# ...                          ...         ...         ...        ...       ...
# 2023-05-12 14:40:00  3944.688000    0.000718    0.000819  -0.000015 -0.000642
# 2023-05-12 14:45:00  3943.251063    0.000503    0.000513  -0.000084 -0.000538
# 2023-05-12 14:50:00  3942.197849   -0.000152    0.000259  -0.000223  0.000299
# 2023-05-12 14:55:00  3940.822651    0.000353    0.000447  -0.000020 -0.000439
# 2023-05-12 15:00:00  3939.657751    0.000333    0.000333  -0.000058 -0.000333
#
#                           ret     ret_5    ret_10    ret_20    vol_48  \
# 2018-01-03 09:35:00  0.001588  0.000584  0.000553  0.000132  0.000903
# 2018-01-03 09:40:00  0.000239  0.000462  0.000407  0.000125  0.000902
# 2018-01-03 09:45:00  0.000847  0.000644  0.000408  0.000142  0.000873
# 2018-01-03 09:50:00  0.002118  0.000961  0.000532  0.000279  0.000834
# 2018-01-03 09:55:00  0.000633  0.001085  0.000628  0.000316  0.000831
# ...                       ...       ...       ...       ...       ...
# 2023-05-12 14:40:00 -0.000641 -0.000248 -0.000187 -0.000321  0.001161
# 2023-05-12 14:45:00 -0.000538 -0.000258 -0.000066 -0.000257  0.001160
# 2023-05-12 14:50:00  0.000300 -0.000291 -0.000151 -0.000243  0.001162
# 2023-05-12 14:55:00 -0.000439 -0.000428 -0.000131 -0.000213  0.001159
# 2023-05-12 15:00:00 -0.000333 -0.000330 -0.000376 -0.000209  0.001159
#
#                      r_vol_48
# 2018-01-03 09:35:00  0.000040
# 2018-01-03 09:40:00  0.000040
# 2018-01-03 09:45:00  0.000038
# 2018-01-03 09:50:00  0.000035
# 2018-01-03 09:55:00  0.000034
# ...                       ...
# 2023-05-12 14:40:00  0.000067
# 2023-05-12 14:45:00  0.000067
# 2023-05-12 14:50:00  0.000067
# 2023-05-12 14:55:00  0.000067
# 2023-05-12 15:00:00  0.000067
#
# [62351 rows x 20 columns]

# %%
df_standard = pd.read_csv(data_path + '/data_process/SH000300_standard.csv', index_col=0)
df_standard.index = pd.to_datetime(df_standard.index)

# %%
import numpy as np
from sklearn.decomposition import PCA

# %%
def pca_roll(df_standard):
    x = df_standard[df_standard.columns].values
    n_total = len(df_standard.columns)
    origin = PCA(n_components=n_total)
    origin_components = origin.fit_transform(x)
    importance = origin.explained_variance_ratio_
    n_chosen = np.where(importance.cumsum() > 0.9)[0][0]
    pca = PCA(n_components=n_chosen)
    pca_components = pca.fit_transform(x)
    # 查看降维后的数据
    df_pca = pd.DataFrame(pca_components, columns=[('PCA_'+str(i)) for i in range(1, n_chosen+1)], index=df_standard.index)
    return df_pca

# %% [markdown]
# 逻辑回归

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# 这里的逻辑回归是基于主观label的，所以这块比较灵活和tricky

# %%
def get_prediction(test_start_date, test_end_date, predict_intervals):
    signal_list = []
    pca_len = len(df_standard.loc[:test_start_date].index)
    for i in df_standard.loc[test_start_date:test_end_date].index[::predict_intervals]:
        print(i)
        df_pca = pca_roll(df_standard.loc[:i].iloc[-pca_len:])
        df_label = df_pca.shift() # 避免未来数据
        df_label['label'] = df_feature.loc[df_label.index, 'log_ret'].rolling(predict_intervals).sum().shift(-predict_intervals)\
            .apply(lambda x:1 if x>0 else 0) # 主观构建标签
        df_label.dropna(axis=0, inplace=True)
        
        # 创建 X (特征) 和 y (类别标签)
        X = df_label.iloc[:, :-1]
        y = df_label['label']

        # 将 X 和 y 分为两个部分
        X_train, X_test = X.loc[:i].iloc[:-1], X.loc[[i]]
        y_train, y_test = y.loc[:i].iloc[:-1], y.loc[[i]]

        # 检测 logistic regression 模型的性能
        # TODO 添加代码:
        # 1.训练模型,  
        # 2.根据模型, 以 X_test 为输入, 生成变量 y_pred

        logreg = LogisticRegression()
        logreg.fit(X_train, y_train.values.reshape(-1))
        y_pred = logreg.predict(X_test)[0]
        signal_list.append(y_pred)
    return signal_list

# %%
test_start_date = '2022'
test_end_date = '2023-05'
predict_intervals = 6
signal_list = get_prediction(test_start_date, test_end_date, predict_intervals)
# Out:
# 2022-01-04 09:35:00
# 2022-01-04 10:05:00
# 2022-01-04 10:35:00
# 2022-01-04 11:05:00
# 2022-01-04 13:05:00
# 2022-01-04 13:35:00
# 2022-01-04 14:05:00
# 2022-01-04 14:35:00
# 2022-01-05 09:35:00
# 2022-01-05 10:05:00
# 2022-01-05 10:35:00
# 2022-01-05 11:05:00
# 2022-01-05 13:05:00
# 2022-01-05 13:35:00
# 2022-01-05 14:05:00
# 2022-01-05 14:35:00
# 2022-01-06 09:35:00
# 2022-01-06 10:05:00
# 2022-01-06 10:35:00
# 2022-01-06 11:05:00
# 2022-01-06 13:05:00
# 2022-01-06 13:35:00
# 2022-01-06 14:05:00
# 2022-01-06 14:35:00
# 2022-01-07 09:35:00
# 2022-01-07 10:05:00
# 2022-01-07 10:35:00
# 2022-01-07 11:05:00
# 2022-01-07 13:05:00
# 2022-01-07 13:35:00
# 2022-01-07 14:05:00
# 2022-01-07 14:35:00
# 2022-01-10 09:35:00
# 2022-01-10 10:05:00
# 2022-01-10 10:35:00
# 2022-01-10 11:05:00
# 2022-01-10 13:05:00
# 2022-01-10 13:35:00
# 2022-01-10 14:05:00
# 2022-01-10 14:35:00
# 2022-01-11 09:35:00
# 2022-01-11 10:05:00
# 2022-01-11 10:35:00
# 2022-01-11 11:05:00
# 2022-01-11 13:05:00
# 2022-01-11 13:35:00
# 2022-01-11 14:05:00
# 2022-01-11 14:35:00
# 2022-01-12 09:35:00
# 2022-01-12 10:05:00
# 2022-01-12 10:35:00
# 2022-01-12 11:05:00
# 2022-01-12 13:05:00
# 2022-01-12 13:35:00
# 2022-01-12 14:05:00
# 2022-01-12 14:35:00
# 2022-01-13 09:35:00
# 2022-01-13 10:05:00
# 2022-01-13 10:35:00
# 2022-01-13 11:05:00
# 2022-01-13 13:05:00
# 2022-01-13 13:35:00
# 2022-01-13 14:05:00
# 2022-01-13 14:35:00
# 2022-01-14 09:35:00
# 2022-01-14 10:05:00
# 2022-01-14 10:35:00
# 2022-01-14 11:05:00
# 2022-01-14 13:05:00
# 2022-01-14 13:35:00
# 2022-01-14 14:05:00
# 2022-01-14 14:35:00
# 2022-01-17 09:35:00
# 2022-01-17 10:05:00
# 2022-01-17 10:35:00
# 2022-01-17 11:05:00
# 2022-01-17 13:05:00
# 2022-01-17 13:35:00
# 2022-01-17 14:05:00
# 2022-01-17 14:35:00
# 2022-01-18 09:35:00
# 2022-01-18 10:05:00
# 2022-01-18 10:35:00
# 2022-01-18 11:05:00
# 2022-01-18 13:05:00
# 2022-01-18 13:35:00
# 2022-01-18 14:05:00
# 2022-01-18 14:35:00
# 2022-01-19 09:35:00
# 2022-01-19 10:05:00
# 2022-01-19 10:35:00
# 2022-01-19 11:05:00
# 2022-01-19 13:05:00
# 2022-01-19 13:35:00
# 2022-01-19 14:05:00
# 2022-01-19 14:35:00
# 2022-01-20 09:35:00
# 2022-01-20 10:05:00
# 2022-01-20 10:35:00
# 2022-01-20 11:05:00
# 2022-01-20 13:05:00
# 2022-01-20 13:35:00
# 2022-01-20 14:05:00
# 2022-01-20 14:35:00
# 2022-01-21 09:35:00
# 2022-01-21 10:05:00
# 2022-01-21 10:35:00
# 2022-01-21 11:05:00
# 2022-01-21 13:05:00
# 2022-01-21 13:35:00
# 2022-01-21 14:05:00
# 2022-01-21 14:35:00
# 2022-01-24 09:35:00
# 2022-01-24 10:05:00
# 2022-01-24 10:35:00
# 2022-01-24 11:05:00
# 2022-01-24 13:05:00
# 2022-01-24 13:35:00
# 2022-01-24 14:05:00
# 2022-01-24 14:35:00
# 2022-01-25 09:35:00
# 2022-01-25 10:05:00
# 2022-01-25 10:35:00
# 2022-01-25 11:05:00
# 2022-01-25 13:05:00
# 2022-01-25 13:35:00
# 2022-01-25 14:05:00
# 2022-01-25 14:35:00
# 2022-01-26 09:35:00
# 2022-01-26 10:05:00
# 2022-01-26 10:35:00
# 2022-01-26 11:05:00
# 2022-01-26 13:05:00
# 2022-01-26 13:35:00
# 2022-01-26 14:05:00
# 2022-01-26 14:35:00
# 2022-01-27 09:35:00
# 2022-01-27 10:05:00
# 2022-01-27 10:35:00
# 2022-01-27 11:05:00
# 2022-01-27 13:05:00
# 2022-01-27 13:35:00
# 2022-01-27 14:05:00
# 2022-01-27 14:35:00
# 2022-01-28 09:35:00
# 2022-01-28 10:05:00
# 2022-01-28 10:35:00
# 2022-01-28 11:05:00
# 2022-01-28 13:05:00
# 2022-01-28 13:35:00
# 2022-01-28 14:05:00
# 2022-01-28 14:35:00
# 2022-02-07 09:35:00
# 2022-02-07 10:05:00
# 2022-02-07 10:35:00
# 2022-02-07 11:05:00
# 2022-02-07 13:05:00
# 2022-02-07 13:35:00
# 2022-02-07 14:05:00
# 2022-02-07 14:35:00
# 2022-02-08 09:35:00
# 2022-02-08 10:05:00
# 2022-02-08 10:35:00
# 2022-02-08 11:05:00
# 2022-02-08 13:05:00
# 2022-02-08 13:35:00
# 2022-02-08 14:05:00
# 2022-02-08 14:35:00
# 2022-02-09 09:35:00
# 2022-02-09 10:05:00
# 2022-02-09 10:35:00
# 2022-02-09 11:05:00
# 2022-02-09 13:05:00
# 2022-02-09 13:35:00
# 2022-02-09 14:05:00
# 2022-02-09 14:35:00
# 2022-02-10 09:35:00
# 2022-02-10 10:05:00
# 2022-02-10 10:35:00
# 2022-02-10 11:05:00
# 2022-02-10 13:05:00
# 2022-02-10 13:35:00
# 2022-02-10 14:05:00
# 2022-02-10 14:35:00
# 2022-02-11 09:35:00
# 2022-02-11 10:05:00
# 2022-02-11 10:35:00
# 2022-02-11 11:05:00
# 2022-02-11 13:05:00
# 2022-02-11 13:35:00
# 2022-02-11 14:05:00
# 2022-02-11 14:35:00
# 2022-02-14 09:35:00
# 2022-02-14 10:05:00
# 2022-02-14 10:35:00
# 2022-02-14 11:05:00
# 2022-02-14 13:05:00
# 2022-02-14 13:35:00
# 2022-02-14 14:05:00
# 2022-02-14 14:35:00
# 2022-02-15 09:35:00
# 2022-02-15 10:05:00
# 2022-02-15 10:35:00
# 2022-02-15 11:05:00
# 2022-02-15 13:05:00
# 2022-02-15 13:35:00
# 2022-02-15 14:05:00
# 2022-02-15 14:35:00
# 2022-02-16 09:35:00
# 2022-02-16 10:05:00
# 2022-02-16 10:35:00
# 2022-02-16 11:05:00
# 2022-02-16 13:05:00
# 2022-02-16 13:35:00
# 2022-02-16 14:05:00
# 2022-02-16 14:35:00
# 2022-02-17 09:35:00
# 2022-02-17 10:05:00
# 2022-02-17 10:35:00
# 2022-02-17 11:05:00
# 2022-02-17 13:05:00
# 2022-02-17 13:35:00
# 2022-02-17 14:05:00
# 2022-02-17 14:35:00
# 2022-02-18 09:35:00
# 2022-02-18 10:05:00
# 2022-02-18 10:35:00
# 2022-02-18 11:05:00
# 2022-02-18 13:05:00
# 2022-02-18 13:35:00
# 2022-02-18 14:05:00
# 2022-02-18 14:35:00
# 2022-02-21 09:35:00
# 2022-02-21 10:05:00
# 2022-02-21 10:35:00
# 2022-02-21 11:05:00
# 2022-02-21 13:05:00
# 2022-02-21 13:35:00
# 2022-02-21 14:05:00
# 2022-02-21 14:35:00
# 2022-02-22 09:35:00
# 2022-02-22 10:05:00
# 2022-02-22 10:35:00
# 2022-02-22 11:05:00
# 2022-02-22 13:05:00
# 2022-02-22 13:35:00
# 2022-02-22 14:05:00
# 2022-02-22 14:35:00
# 2022-02-23 09:35:00
# 2022-02-23 10:05:00
# 2022-02-23 10:35:00
# 2022-02-23 11:05:00
# 2022-02-23 13:05:00
# 2022-02-23 13:35:00
# 2022-02-23 14:05:00
# 2022-02-23 14:35:00
# 2022-02-24 09:35:00
# 2022-02-24 10:05:00
# 2022-02-24 10:35:00
# 2022-02-24 11:05:00
# 2022-02-24 13:05:00
# 2022-02-24 13:35:00
# 2022-02-24 14:05:00
# 2022-02-24 14:35:00
# 2022-02-25 09:35:00
# 2022-02-25 10:05:00
# 2022-02-25 10:35:00
# 2022-02-25 11:05:00
# 2022-02-25 13:05:00
# 2022-02-25 13:35:00
# 2022-02-25 14:05:00
# 2022-02-25 14:35:00
# 2022-02-28 09:35:00
# 2022-02-28 10:05:00
# 2022-02-28 10:35:00
# 2022-02-28 11:05:00
# 2022-02-28 13:05:00
# 2022-02-28 13:35:00
# 2022-02-28 14:05:00
# 2022-02-28 14:35:00
# 2022-03-01 09:35:00
# 2022-03-01 10:05:00
# 2022-03-01 10:35:00
# 2022-03-01 11:05:00
# 2022-03-01 13:05:00
# 2022-03-01 13:35:00
# 2022-03-01 14:05:00
# 2022-03-01 14:35:00
# 2022-03-02 09:35:00
# 2022-03-02 10:05:00
# 2022-03-02 10:35:00
# 2022-03-02 11:05:00
# 2022-03-02 13:05:00
# 2022-03-02 13:35:00
# 2022-03-02 14:05:00
# 2022-03-02 14:35:00
# 2022-03-03 09:35:00
# 2022-03-03 10:05:00
# 2022-03-03 10:35:00
# 2022-03-03 11:05:00
# 2022-03-03 13:05:00
# 2022-03-03 13:35:00
# 2022-03-03 14:05:00
# 2022-03-03 14:35:00
# 2022-03-04 09:35:00
# 2022-03-04 10:05:00
# 2022-03-04 10:35:00
# 2022-03-04 11:05:00
# 2022-03-04 13:05:00
# 2022-03-04 13:35:00
# 2022-03-04 14:05:00
# 2022-03-04 14:35:00
# 2022-03-07 09:35:00
# 2022-03-07 10:05:00
# 2022-03-07 10:35:00
# 2022-03-07 11:05:00
# 2022-03-07 13:05:00
# 2022-03-07 13:35:00
# 2022-03-07 14:05:00
# 2022-03-07 14:35:00
# 2022-03-08 09:35:00
# 2022-03-08 10:05:00
# 2022-03-08 10:35:00
# 2022-03-08 11:05:00
# 2022-03-08 13:05:00
# 2022-03-08 13:35:00
# 2022-03-08 14:05:00
# 2022-03-08 14:35:00
# 2022-03-09 09:35:00
# 2022-03-09 10:05:00
# 2022-03-09 10:35:00
# 2022-03-09 11:05:00
# 2022-03-09 13:05:00
# 2022-03-09 13:35:00
# 2022-03-09 14:05:00
# 2022-03-09 14:35:00
# 2022-03-10 09:35:00
# 2022-03-10 10:05:00
# 2022-03-10 10:35:00
# 2022-03-10 11:05:00
# 2022-03-10 13:05:00
# 2022-03-10 13:35:00
# 2022-03-10 14:05:00
# 2022-03-10 14:35:00
# 2022-03-11 09:35:00
# 2022-03-11 10:05:00
# 2022-03-11 10:35:00
# 2022-03-11 11:05:00
# 2022-03-11 13:05:00
# 2022-03-11 13:35:00
# 2022-03-11 14:05:00
# 2022-03-11 14:35:00
# 2022-03-14 09:35:00
# 2022-03-14 10:05:00
# 2022-03-14 10:35:00
# 2022-03-14 11:05:00
# 2022-03-14 13:05:00
# 2022-03-14 13:35:00
# 2022-03-14 14:05:00
# 2022-03-14 14:35:00
# 2022-03-15 09:35:00
# 2022-03-15 10:05:00
# 2022-03-15 10:35:00
# 2022-03-15 11:05:00
# 2022-03-15 13:05:00
# 2022-03-15 13:35:00
# 2022-03-15 14:05:00
# 2022-03-15 14:35:00
# 2022-03-16 09:35:00
# 2022-03-16 10:05:00
# 2022-03-16 10:35:00
# 2022-03-16 11:05:00
# 2022-03-16 13:05:00
# 2022-03-16 13:35:00
# 2022-03-16 14:05:00
# 2022-03-16 14:35:00
# 2022-03-17 09:35:00
# 2022-03-17 10:05:00
# 2022-03-17 10:35:00
# 2022-03-17 11:05:00
# 2022-03-17 13:05:00
# 2022-03-17 13:35:00
# 2022-03-17 14:05:00
# 2022-03-17 14:35:00
# 2022-03-18 09:35:00
# 2022-03-18 10:05:00
# 2022-03-18 10:35:00
# 2022-03-18 11:05:00
# 2022-03-18 13:05:00
# 2022-03-18 13:35:00
# 2022-03-18 14:05:00
# 2022-03-18 14:35:00
# 2022-03-21 09:35:00
# 2022-03-21 10:05:00
# 2022-03-21 10:35:00
# 2022-03-21 11:05:00
# 2022-03-21 13:05:00
# 2022-03-21 13:35:00
# 2022-03-21 14:05:00
# 2022-03-21 14:35:00
# 2022-03-22 09:35:00
# 2022-03-22 10:05:00
# 2022-03-22 10:35:00
# 2022-03-22 11:05:00
# 2022-03-22 13:05:00
# 2022-03-22 13:35:00
# 2022-03-22 14:05:00
# 2022-03-22 14:35:00
# 2022-03-23 09:35:00
# 2022-03-23 10:05:00
# 2022-03-23 10:35:00
# 2022-03-23 11:05:00
# 2022-03-23 13:05:00
# 2022-03-23 13:35:00
# 2022-03-23 14:05:00
# 2022-03-23 14:35:00
# 2022-03-24 09:35:00
# 2022-03-24 10:05:00
# 2022-03-24 10:35:00
# 2022-03-24 11:05:00
# 2022-03-24 13:05:00
# 2022-03-24 13:35:00
# 2022-03-24 14:05:00
# 2022-03-24 14:35:00
# 2022-03-25 09:35:00
# 2022-03-25 10:05:00
# 2022-03-25 10:35:00
# 2022-03-25 11:05:00
# 2022-03-25 13:05:00
# 2022-03-25 13:35:00
# 2022-03-25 14:05:00
# 2022-03-25 14:35:00
# 2022-03-28 09:35:00
# 2022-03-28 10:05:00
# 2022-03-28 10:35:00
# 2022-03-28 11:05:00
# 2022-03-28 13:05:00
# 2022-03-28 13:35:00
# 2022-03-28 14:05:00
# 2022-03-28 14:35:00
# 2022-03-29 09:35:00
# 2022-03-29 10:05:00
# 2022-03-29 10:35:00
# 2022-03-29 11:05:00
# 2022-03-29 13:05:00
# 2022-03-29 13:35:00
# 2022-03-29 14:05:00
# 2022-03-29 14:35:00
# 2022-03-30 09:35:00
# 2022-03-30 10:05:00
# 2022-03-30 10:35:00
# 2022-03-30 11:05:00
# 2022-03-30 13:05:00
# 2022-03-30 13:35:00
# 2022-03-30 14:05:00
# 2022-03-30 14:35:00
# 2022-03-31 09:35:00
# 2022-03-31 10:05:00
# 2022-03-31 10:35:00
# 2022-03-31 11:05:00
# 2022-03-31 13:05:00
# 2022-03-31 13:35:00
# 2022-03-31 14:05:00
# 2022-03-31 14:35:00
# 2022-04-01 09:35:00
# 2022-04-01 10:05:00
# 2022-04-01 10:35:00
# 2022-04-01 11:05:00
# 2022-04-01 13:05:00
# 2022-04-01 13:35:00
# 2022-04-01 14:05:00
# 2022-04-01 14:35:00
# 2022-04-06 09:35:00
# 2022-04-06 10:05:00
# 2022-04-06 10:35:00
# 2022-04-06 11:05:00
# 2022-04-06 13:05:00
# 2022-04-06 13:35:00
# 2022-04-06 14:05:00
# 2022-04-06 14:35:00
# 2022-04-07 09:35:00
# 2022-04-07 10:05:00
# 2022-04-07 10:35:00
# 2022-04-07 11:05:00
# 2022-04-07 13:05:00
# 2022-04-07 13:35:00
# 2022-04-07 14:05:00
# 2022-04-07 14:35:00
# 2022-04-08 09:35:00
# 2022-04-08 10:05:00
# 2022-04-08 10:35:00
# 2022-04-08 11:05:00
# 2022-04-08 13:05:00
# 2022-04-08 13:35:00
# 2022-04-08 14:05:00
# 2022-04-08 14:35:00
# 2022-04-11 09:35:00
# 2022-04-11 10:05:00
# 2022-04-11 10:35:00
# 2022-04-11 11:05:00
# 2022-04-11 13:05:00
# 2022-04-11 13:35:00
# 2022-04-11 14:05:00
# 2022-04-11 14:35:00
# 2022-04-12 09:35:00
# 2022-04-12 10:05:00
# 2022-04-12 10:35:00
# 2022-04-12 11:05:00
# 2022-04-12 13:05:00
# 2022-04-12 13:35:00
# 2022-04-12 14:05:00
# 2022-04-12 14:35:00
# 2022-04-13 09:35:00
# 2022-04-13 10:05:00
# 2022-04-13 10:35:00
# 2022-04-13 11:05:00
# 2022-04-13 13:05:00
# 2022-04-13 13:35:00
# 2022-04-13 14:05:00
# 2022-04-13 14:35:00
# 2022-04-14 09:35:00
# 2022-04-14 10:05:00
# 2022-04-14 10:35:00
# 2022-04-14 11:05:00
# 2022-04-14 13:05:00
# 2022-04-14 13:35:00
# 2022-04-14 14:05:00
# 2022-04-14 14:35:00
# 2022-04-15 09:35:00
# 2022-04-15 10:05:00
# 2022-04-15 10:35:00
# 2022-04-15 11:05:00
# 2022-04-15 13:05:00
# 2022-04-15 13:35:00
# 2022-04-15 14:05:00
# 2022-04-15 14:35:00
# 2022-04-18 09:35:00
# 2022-04-18 10:05:00
# 2022-04-18 10:35:00
# 2022-04-18 11:05:00
# 2022-04-18 13:05:00
# 2022-04-18 13:35:00
# 2022-04-18 14:05:00
# 2022-04-18 14:35:00
# 2022-04-19 09:35:00
# 2022-04-19 10:05:00
# 2022-04-19 10:35:00
# 2022-04-19 11:05:00
# 2022-04-19 13:05:00
# 2022-04-19 13:35:00
# 2022-04-19 14:05:00
# 2022-04-19 14:35:00
# 2022-04-20 09:35:00
# 2022-04-20 10:05:00
# 2022-04-20 10:35:00
# 2022-04-20 11:05:00
# 2022-04-20 13:05:00
# 2022-04-20 13:35:00
# 2022-04-20 14:05:00
# 2022-04-20 14:35:00
# 2022-04-21 09:35:00
# 2022-04-21 10:05:00
# 2022-04-21 10:35:00
# 2022-04-21 11:05:00
# 2022-04-21 13:05:00
# 2022-04-21 13:35:00
# 2022-04-21 14:05:00
# 2022-04-21 14:35:00
# 2022-04-22 09:35:00
# 2022-04-22 10:05:00
# 2022-04-22 10:35:00
# 2022-04-22 11:05:00
# 2022-04-22 13:05:00
# 2022-04-22 13:35:00
# 2022-04-22 14:05:00
# 2022-04-22 14:35:00
# 2022-04-25 09:35:00
# 2022-04-25 10:05:00
# 2022-04-25 10:35:00
# 2022-04-25 11:05:00
# 2022-04-25 13:05:00
# 2022-04-25 13:35:00
# 2022-04-25 14:05:00
# 2022-04-25 14:35:00
# 2022-04-26 09:35:00
# 2022-04-26 10:05:00
# 2022-04-26 10:35:00
# 2022-04-26 11:05:00
# 2022-04-26 13:05:00
# 2022-04-26 13:35:00
# 2022-04-26 14:05:00
# 2022-04-26 14:35:00
# 2022-04-27 09:35:00
# 2022-04-27 10:05:00
# 2022-04-27 10:35:00
# 2022-04-27 11:05:00
# 2022-04-27 13:05:00
# 2022-04-27 13:35:00
# 2022-04-27 14:05:00
# 2022-04-27 14:35:00
# 2022-04-28 09:35:00
# 2022-04-28 10:05:00
# 2022-04-28 10:35:00
# 2022-04-28 11:05:00
# 2022-04-28 13:05:00
# 2022-04-28 13:35:00
# 2022-04-28 14:05:00
# 2022-04-28 14:35:00
# 2022-04-29 09:35:00
# 2022-04-29 10:05:00
# 2022-04-29 10:35:00
# 2022-04-29 11:05:00
# 2022-04-29 13:05:00
# 2022-04-29 13:35:00
# 2022-04-29 14:05:00
# 2022-04-29 14:35:00
# 2022-05-05 09:35:00
# 2022-05-05 10:05:00
# 2022-05-05 10:35:00
# 2022-05-05 11:05:00
# 2022-05-05 13:05:00
# 2022-05-05 13:35:00
# 2022-05-05 14:05:00
# 2022-05-05 14:35:00
# 2022-05-06 09:35:00
# 2022-05-06 10:05:00
# 2022-05-06 10:35:00
# 2022-05-06 11:05:00
# 2022-05-06 13:05:00
# 2022-05-06 13:35:00
# 2022-05-06 14:05:00
# 2022-05-06 14:35:00
# 2022-05-09 09:35:00
# 2022-05-09 10:05:00
# 2022-05-09 10:35:00
# 2022-05-09 11:05:00
# 2022-05-09 13:05:00
# 2022-05-09 13:35:00
# 2022-05-09 14:05:00
# 2022-05-09 14:35:00
# 2022-05-10 09:35:00
# 2022-05-10 10:05:00
# 2022-05-10 10:35:00
# 2022-05-10 11:05:00
# 2022-05-10 13:05:00
# 2022-05-10 13:35:00
# 2022-05-10 14:05:00
# 2022-05-10 14:35:00
# 2022-05-11 09:35:00
# 2022-05-11 10:05:00
# 2022-05-11 10:35:00
# 2022-05-11 11:05:00
# 2022-05-11 13:05:00
# 2022-05-11 13:35:00
# 2022-05-11 14:05:00
# 2022-05-11 14:35:00
# 2022-05-12 09:35:00
# 2022-05-12 10:05:00
# 2022-05-12 10:35:00
# 2022-05-12 11:05:00
# 2022-05-12 13:05:00
# 2022-05-12 13:35:00
# 2022-05-12 14:05:00
# 2022-05-12 14:35:00
# 2022-05-13 09:35:00
# 2022-05-13 10:05:00
# 2022-05-13 10:35:00
# 2022-05-13 11:05:00
# 2022-05-13 13:05:00
# 2022-05-13 13:35:00
# 2022-05-13 14:05:00
# 2022-05-13 14:35:00
# 2022-05-16 09:35:00
# 2022-05-16 10:05:00
# 2022-05-16 10:35:00
# 2022-05-16 11:05:00
# 2022-05-16 13:05:00
# 2022-05-16 13:35:00
# 2022-05-16 14:05:00
# 2022-05-16 14:35:00
# 2022-05-17 09:35:00
# 2022-05-17 10:05:00
# 2022-05-17 10:35:00
# 2022-05-17 11:05:00
# 2022-05-17 13:05:00
# 2022-05-17 13:35:00
# 2022-05-17 14:05:00
# 2022-05-17 14:35:00
# 2022-05-18 09:35:00
# 2022-05-18 10:05:00
# 2022-05-18 10:35:00
# 2022-05-18 11:05:00
# 2022-05-18 13:05:00
# 2022-05-18 13:35:00
# 2022-05-18 14:05:00
# 2022-05-18 14:35:00
# 2022-05-19 09:35:00
# 2022-05-19 10:05:00
# 2022-05-19 10:35:00
# 2022-05-19 11:05:00
# 2022-05-19 13:05:00
# 2022-05-19 13:35:00
# 2022-05-19 14:05:00
# 2022-05-19 14:35:00
# 2022-05-20 09:35:00
# 2022-05-20 10:05:00
# 2022-05-20 10:35:00
# 2022-05-20 11:05:00
# 2022-05-20 13:05:00
# 2022-05-20 13:35:00
# 2022-05-20 14:05:00
# 2022-05-20 14:35:00
# 2022-05-23 09:35:00
# 2022-05-23 10:05:00
# 2022-05-23 10:35:00
# 2022-05-23 11:05:00
# 2022-05-23 13:05:00
# 2022-05-23 13:35:00
# 2022-05-23 14:05:00
# 2022-05-23 14:35:00
# 2022-05-24 09:35:00
# 2022-05-24 10:05:00
# 2022-05-24 10:35:00
# 2022-05-24 11:05:00
# 2022-05-24 13:05:00
# 2022-05-24 13:35:00
# 2022-05-24 14:05:00
# 2022-05-24 14:35:00
# 2022-05-25 09:35:00
# 2022-05-25 10:05:00
# 2022-05-25 10:35:00
# 2022-05-25 11:05:00
# 2022-05-25 13:05:00
# 2022-05-25 13:35:00
# 2022-05-25 14:05:00
# 2022-05-25 14:35:00
# 2022-05-26 09:35:00
# 2022-05-26 10:05:00
# 2022-05-26 10:35:00
# 2022-05-26 11:05:00
# 2022-05-26 13:05:00
# 2022-05-26 13:35:00
# 2022-05-26 14:05:00
# 2022-05-26 14:35:00
# 2022-05-27 09:35:00
# 2022-05-27 10:05:00
# 2022-05-27 10:35:00
# 2022-05-27 11:05:00
# 2022-05-27 13:05:00
# 2022-05-27 13:35:00
# 2022-05-27 14:05:00
# 2022-05-27 14:35:00
# 2022-05-30 09:35:00
# 2022-05-30 10:05:00
# 2022-05-30 10:35:00
# 2022-05-30 11:05:00
# 2022-05-30 13:05:00
# 2022-05-30 13:35:00
# 2022-05-30 14:05:00
# 2022-05-30 14:35:00
# 2022-05-31 09:35:00
# 2022-05-31 10:05:00
# 2022-05-31 10:35:00
# 2022-05-31 11:05:00
# 2022-05-31 13:05:00
# 2022-05-31 13:35:00
# 2022-05-31 14:05:00
# 2022-05-31 14:35:00
# 2022-06-01 09:35:00
# 2022-06-01 10:05:00
# 2022-06-01 10:35:00
# 2022-06-01 11:05:00
# 2022-06-01 13:05:00
# 2022-06-01 13:35:00
# 2022-06-01 14:05:00
# 2022-06-01 14:35:00
# 2022-06-02 09:35:00
# 2022-06-02 10:05:00
# 2022-06-02 10:35:00
# 2022-06-02 11:05:00
# 2022-06-02 13:05:00
# 2022-06-02 13:35:00
# 2022-06-02 14:05:00
# 2022-06-02 14:35:00
# 2022-06-06 09:35:00
# 2022-06-06 10:05:00
# 2022-06-06 10:35:00
# 2022-06-06 11:05:00
# 2022-06-06 13:05:00
# 2022-06-06 13:35:00
# 2022-06-06 14:05:00
# 2022-06-06 14:35:00
# 2022-06-07 09:35:00
# 2022-06-07 10:05:00
# 2022-06-07 10:35:00
# 2022-06-07 11:05:00
# 2022-06-07 13:05:00
# 2022-06-07 13:35:00
# 2022-06-07 14:05:00
# 2022-06-07 14:35:00
# 2022-06-08 09:35:00
# 2022-06-08 10:05:00
# 2022-06-08 10:35:00
# 2022-06-08 11:05:00
# 2022-06-08 13:05:00
# 2022-06-08 13:35:00
# 2022-06-08 14:05:00
# 2022-06-08 14:35:00
# 2022-06-09 09:35:00
# 2022-06-09 10:05:00
# 2022-06-09 10:35:00
# 2022-06-09 11:05:00
# 2022-06-09 13:05:00
# 2022-06-09 13:35:00
# 2022-06-09 14:05:00
# 2022-06-09 14:35:00
# 2022-06-10 09:35:00
# 2022-06-10 10:05:00
# 2022-06-10 10:35:00
# 2022-06-10 11:05:00
# 2022-06-10 13:05:00
# 2022-06-10 13:35:00
# 2022-06-10 14:05:00
# 2022-06-10 14:35:00
# 2022-06-13 09:35:00
# 2022-06-13 10:05:00
# 2022-06-13 10:35:00
# 2022-06-13 11:05:00
# 2022-06-13 13:05:00
# 2022-06-13 13:35:00
# 2022-06-13 14:05:00
# 2022-06-13 14:35:00
# 2022-06-14 09:35:00
# 2022-06-14 10:05:00
# 2022-06-14 10:35:00
# 2022-06-14 11:05:00
# 2022-06-14 13:05:00
# 2022-06-14 13:35:00
# 2022-06-14 14:05:00
# 2022-06-14 14:35:00
# 2022-06-15 09:35:00
# 2022-06-15 10:05:00
# 2022-06-15 10:35:00
# 2022-06-15 11:05:00
# 2022-06-15 13:05:00
# 2022-06-15 13:35:00
# 2022-06-15 14:05:00
# 2022-06-15 14:35:00
# 2022-06-16 09:35:00
# 2022-06-16 10:05:00
# 2022-06-16 10:35:00
# 2022-06-16 11:05:00
# 2022-06-16 13:05:00
# 2022-06-16 13:35:00
# 2022-06-16 14:05:00
# 2022-06-16 14:35:00
# 2022-06-17 09:35:00
# 2022-06-17 10:05:00
# 2022-06-17 10:35:00
# 2022-06-17 11:05:00
# 2022-06-17 13:05:00
# 2022-06-17 13:35:00
# 2022-06-17 14:05:00
# 2022-06-17 14:35:00
# 2022-06-20 09:35:00
# 2022-06-20 10:05:00
# 2022-06-20 10:35:00
# 2022-06-20 11:05:00
# 2022-06-20 13:05:00
# 2022-06-20 13:35:00
# 2022-06-20 14:05:00
# 2022-06-20 14:35:00
# 2022-06-21 09:35:00
# 2022-06-21 10:05:00
# 2022-06-21 10:35:00
# 2022-06-21 11:05:00
# 2022-06-21 13:05:00
# 2022-06-21 13:35:00
# 2022-06-21 14:05:00
# 2022-06-21 14:35:00
# 2022-06-22 09:35:00
# 2022-06-22 10:05:00
# 2022-06-22 10:35:00
# 2022-06-22 11:05:00
# 2022-06-22 13:05:00
# 2022-06-22 13:35:00
# 2022-06-22 14:05:00
# 2022-06-22 14:35:00
# 2022-06-23 09:35:00
# 2022-06-23 10:05:00
# 2022-06-23 10:35:00
# 2022-06-23 11:05:00
# 2022-06-23 13:05:00
# 2022-06-23 13:35:00
# 2022-06-23 14:05:00
# 2022-06-23 14:35:00
# 2022-06-24 09:35:00
# 2022-06-24 10:05:00
# 2022-06-24 10:35:00
# 2022-06-24 11:05:00
# 2022-06-24 13:05:00
# 2022-06-24 13:35:00
# 2022-06-24 14:05:00
# 2022-06-24 14:35:00
# 2022-06-27 09:35:00
# 2022-06-27 10:05:00
# 2022-06-27 10:35:00
# 2022-06-27 11:05:00
# 2022-06-27 13:05:00
# 2022-06-27 13:35:00
# 2022-06-27 14:05:00
# 2022-06-27 14:35:00
# 2022-06-28 09:35:00
# 2022-06-28 10:05:00
# 2022-06-28 10:35:00
# 2022-06-28 11:05:00
# 2022-06-28 13:05:00
# 2022-06-28 13:35:00
# 2022-06-28 14:05:00
# 2022-06-28 14:35:00
# 2022-06-29 09:35:00
# 2022-06-29 10:05:00
# 2022-06-29 10:35:00
# 2022-06-29 11:05:00
# 2022-06-29 13:05:00
# 2022-06-29 13:35:00
# 2022-06-29 14:05:00
# 2022-06-29 14:35:00
# 2022-06-30 09:35:00
# 2022-06-30 10:05:00
# 2022-06-30 10:35:00
# 2022-06-30 11:05:00
# 2022-06-30 13:05:00
# 2022-06-30 13:35:00
# 2022-06-30 14:05:00
# 2022-06-30 14:35:00
# 2022-07-01 09:35:00
# 2022-07-01 10:05:00
# 2022-07-01 10:35:00
# 2022-07-01 11:05:00
# 2022-07-01 13:05:00
# 2022-07-01 13:35:00
# 2022-07-01 14:05:00
# 2022-07-01 14:35:00
# 2022-07-04 09:35:00
# 2022-07-04 10:05:00
# 2022-07-04 10:35:00
# 2022-07-04 11:05:00
# 2022-07-04 13:05:00
# 2022-07-04 13:35:00
# 2022-07-04 14:05:00
# 2022-07-04 14:35:00
# 2022-07-05 09:35:00
# 2022-07-05 10:05:00
# 2022-07-05 10:35:00
# 2022-07-05 11:05:00
# 2022-07-05 13:05:00
# 2022-07-05 13:35:00
# 2022-07-05 14:05:00
# 2022-07-05 14:35:00
# 2022-07-06 09:35:00
# 2022-07-06 10:05:00
# 2022-07-06 10:35:00
# 2022-07-06 11:05:00
# 2022-07-06 13:05:00
# 2022-07-06 13:35:00
# 2022-07-06 14:05:00
# 2022-07-06 14:35:00
# 2022-07-07 09:35:00
# 2022-07-07 10:05:00
# 2022-07-07 10:35:00
# 2022-07-07 11:05:00
# 2022-07-07 13:05:00
# 2022-07-07 13:35:00
# 2022-07-07 14:05:00
# 2022-07-07 14:35:00
# 2022-07-08 09:35:00
# 2022-07-08 10:05:00
# 2022-07-08 10:35:00
# 2022-07-08 11:05:00
# 2022-07-08 13:05:00
# 2022-07-08 13:35:00
# 2022-07-08 14:05:00
# 2022-07-08 14:35:00
# 2022-07-11 09:35:00
# 2022-07-11 10:05:00
# 2022-07-11 10:35:00
# 2022-07-11 11:05:00
# 2022-07-11 13:05:00
# 2022-07-11 13:35:00
# 2022-07-11 14:05:00
# 2022-07-11 14:35:00
# 2022-07-12 09:35:00
# 2022-07-12 10:05:00
# 2022-07-12 10:35:00
# 2022-07-12 11:05:00
# 2022-07-12 13:05:00
# 2022-07-12 13:35:00
# 2022-07-12 14:05:00
# 2022-07-12 14:35:00
# 2022-07-13 09:35:00
# 2022-07-13 10:05:00
# 2022-07-13 10:35:00
# 2022-07-13 11:05:00
# 2022-07-13 13:05:00
# 2022-07-13 13:35:00
# 2022-07-13 14:05:00
# 2022-07-13 14:35:00
# 2022-07-14 09:35:00
# 2022-07-14 10:05:00
# 2022-07-14 10:35:00
# 2022-07-14 11:05:00
# 2022-07-14 13:05:00
# 2022-07-14 13:35:00
# 2022-07-14 14:05:00
# 2022-07-14 14:35:00
# 2022-07-15 09:35:00
# 2022-07-15 10:05:00
# 2022-07-15 10:35:00
# 2022-07-15 11:05:00
# 2022-07-15 13:05:00
# 2022-07-15 13:35:00
# 2022-07-15 14:05:00
# 2022-07-15 14:35:00
# 2022-07-18 09:35:00
# 2022-07-18 10:05:00
# 2022-07-18 10:35:00
# 2022-07-18 11:05:00
# 2022-07-18 13:05:00
# 2022-07-18 13:35:00
# 2022-07-18 14:05:00
# 2022-07-18 14:35:00
# 2022-07-19 09:35:00
# 2022-07-19 10:05:00
# 2022-07-19 10:35:00
# 2022-07-19 11:05:00
# 2022-07-19 13:05:00
# 2022-07-19 13:35:00
# 2022-07-19 14:05:00
# 2022-07-19 14:35:00
# 2022-07-20 09:35:00
# 2022-07-20 10:05:00
# 2022-07-20 10:35:00
# 2022-07-20 11:05:00
# 2022-07-20 13:05:00
# 2022-07-20 13:35:00
# 2022-07-20 14:05:00
# 2022-07-20 14:35:00
# 2022-07-21 09:35:00
# 2022-07-21 10:05:00
# 2022-07-21 10:35:00
# 2022-07-21 11:05:00
# 2022-07-21 13:05:00
# 2022-07-21 13:35:00
# 2022-07-21 14:05:00
# 2022-07-21 14:35:00
# 2022-07-22 09:35:00
# 2022-07-22 10:05:00
# 2022-07-22 10:35:00
# 2022-07-22 11:05:00
# 2022-07-22 13:05:00
# 2022-07-22 13:35:00
# 2022-07-22 14:05:00
# 2022-07-22 14:35:00
# 2022-07-25 09:35:00
# 2022-07-25 10:05:00
# 2022-07-25 10:35:00
# 2022-07-25 11:05:00
# 2022-07-25 13:05:00
# 2022-07-25 13:35:00
# 2022-07-25 14:05:00
# 2022-07-25 14:35:00
# 2022-07-26 09:35:00
# 2022-07-26 10:05:00
# 2022-07-26 10:35:00
# 2022-07-26 11:05:00
# 2022-07-26 13:05:00
# 2022-07-26 13:35:00
# 2022-07-26 14:05:00
# 2022-07-26 14:35:00
# 2022-07-27 09:35:00
# 2022-07-27 10:05:00
# 2022-07-27 10:35:00
# 2022-07-27 11:05:00
# 2022-07-27 13:05:00
# 2022-07-27 13:35:00
# 2022-07-27 14:05:00
# 2022-07-27 14:35:00
# 2022-07-28 09:35:00
# 2022-07-28 10:05:00
# 2022-07-28 10:35:00
# 2022-07-28 11:05:00
# 2022-07-28 13:05:00
# 2022-07-28 13:35:00
# 2022-07-28 14:05:00
# 2022-07-28 14:35:00
# 2022-07-29 09:35:00
# 2022-07-29 10:05:00
# 2022-07-29 10:35:00
# 2022-07-29 11:05:00
# 2022-07-29 13:05:00
# 2022-07-29 13:35:00
# 2022-07-29 14:05:00
# 2022-07-29 14:35:00
# 2022-08-01 09:35:00
# 2022-08-01 10:05:00
# 2022-08-01 10:35:00
# 2022-08-01 11:05:00
# 2022-08-01 13:05:00
# 2022-08-01 13:35:00
# 2022-08-01 14:05:00
# 2022-08-01 14:35:00
# 2022-08-02 09:35:00
# 2022-08-02 10:05:00
# 2022-08-02 10:35:00
# 2022-08-02 11:05:00
# 2022-08-02 13:05:00
# 2022-08-02 13:35:00
# 2022-08-02 14:05:00
# 2022-08-02 14:35:00
# 2022-08-03 09:35:00
# 2022-08-03 10:05:00
# 2022-08-03 10:35:00
# 2022-08-03 11:05:00
# 2022-08-03 13:05:00
# 2022-08-03 13:35:00
# 2022-08-03 14:05:00
# 2022-08-03 14:35:00
# 2022-08-04 09:35:00
# 2022-08-04 10:05:00
# 2022-08-04 10:35:00
# 2022-08-04 11:05:00
# 2022-08-04 13:05:00
# 2022-08-04 13:35:00
# 2022-08-04 14:05:00
# 2022-08-04 14:35:00
# 2022-08-05 09:35:00
# 2022-08-05 10:05:00
# 2022-08-05 10:35:00
# 2022-08-05 11:05:00
# 2022-08-05 13:05:00
# 2022-08-05 13:35:00
# 2022-08-05 14:05:00
# 2022-08-05 14:35:00
# 2022-08-08 09:35:00
# 2022-08-08 10:05:00
# 2022-08-08 10:35:00
# 2022-08-08 11:05:00
# 2022-08-08 13:05:00
# 2022-08-08 13:35:00
# 2022-08-08 14:05:00
# 2022-08-08 14:35:00
# 2022-08-09 09:35:00
# 2022-08-09 10:05:00
# 2022-08-09 10:35:00
# 2022-08-09 11:05:00
# 2022-08-09 13:05:00
# 2022-08-09 13:35:00
# 2022-08-09 14:05:00
# 2022-08-09 14:35:00
# 2022-08-10 09:35:00
# 2022-08-10 10:05:00
# 2022-08-10 10:35:00
# 2022-08-10 11:05:00
# 2022-08-10 13:05:00
# 2022-08-10 13:35:00
# 2022-08-10 14:05:00
# 2022-08-10 14:35:00
# 2022-08-11 09:35:00
# 2022-08-11 10:05:00
# 2022-08-11 10:35:00
# 2022-08-11 11:05:00
# 2022-08-11 13:05:00
# 2022-08-11 13:35:00
# 2022-08-11 14:05:00
# 2022-08-11 14:35:00
# 2022-08-12 09:35:00
# 2022-08-12 10:05:00
# 2022-08-12 10:35:00
# 2022-08-12 11:05:00
# 2022-08-12 13:05:00
# 2022-08-12 13:35:00
# 2022-08-12 14:05:00
# 2022-08-12 14:35:00
# 2022-08-15 09:35:00
# 2022-08-15 10:05:00
# 2022-08-15 10:35:00
# 2022-08-15 11:05:00
# 2022-08-15 13:05:00
# 2022-08-15 13:35:00
# 2022-08-15 14:05:00
# 2022-08-15 14:35:00
# 2022-08-16 09:35:00
# 2022-08-16 10:05:00
# 2022-08-16 10:35:00
# 2022-08-16 11:05:00
# 2022-08-16 13:05:00
# 2022-08-16 13:35:00
# 2022-08-16 14:05:00
# 2022-08-16 14:35:00
# 2022-08-17 09:35:00
# 2022-08-17 10:05:00
# 2022-08-17 10:35:00
# 2022-08-17 11:05:00
# 2022-08-17 13:05:00
# 2022-08-17 13:35:00
# 2022-08-17 14:05:00
# 2022-08-17 14:35:00
# 2022-08-18 09:35:00
# 2022-08-18 10:05:00
# 2022-08-18 10:35:00
# 2022-08-18 11:05:00
# 2022-08-18 13:05:00
# 2022-08-18 13:35:00
# 2022-08-18 14:05:00
# 2022-08-18 14:35:00
# 2022-08-19 09:35:00
# 2022-08-19 10:05:00
# 2022-08-19 10:35:00
# 2022-08-19 11:05:00
# 2022-08-19 13:05:00
# 2022-08-19 13:35:00
# 2022-08-19 14:05:00
# 2022-08-19 14:35:00
# 2022-08-22 09:35:00
# 2022-08-22 10:05:00
# 2022-08-22 10:35:00
# 2022-08-22 11:05:00
# 2022-08-22 13:05:00
# 2022-08-22 13:35:00
# 2022-08-22 14:05:00
# 2022-08-22 14:35:00
# 2022-08-23 09:35:00
# 2022-08-23 10:05:00
# 2022-08-23 10:35:00
# 2022-08-23 11:05:00
# 2022-08-23 13:05:00
# 2022-08-23 13:35:00
# 2022-08-23 14:05:00
# 2022-08-23 14:35:00
# 2022-08-24 09:35:00
# 2022-08-24 10:05:00
# 2022-08-24 10:35:00
# 2022-08-24 11:05:00
# 2022-08-24 13:05:00
# 2022-08-24 13:35:00
# 2022-08-24 14:05:00
# 2022-08-24 14:35:00
# 2022-08-25 09:35:00
# 2022-08-25 10:05:00
# 2022-08-25 10:35:00
# 2022-08-25 11:05:00
# 2022-08-25 13:05:00
# 2022-08-25 13:35:00
# 2022-08-25 14:05:00
# 2022-08-25 14:35:00
# 2022-08-26 09:35:00
# 2022-08-26 10:05:00
# 2022-08-26 10:35:00
# 2022-08-26 11:05:00
# 2022-08-26 13:05:00
# 2022-08-26 13:35:00
# 2022-08-26 14:05:00
# 2022-08-26 14:35:00
# 2022-08-29 09:35:00
# 2022-08-29 10:05:00
# 2022-08-29 10:35:00
# 2022-08-29 11:05:00
# 2022-08-29 13:05:00
# 2022-08-29 13:35:00
# 2022-08-29 14:05:00
# 2022-08-29 14:35:00
# 2022-08-30 09:35:00
# 2022-08-30 10:05:00
# 2022-08-30 10:35:00
# 2022-08-30 11:05:00
# 2022-08-30 13:05:00
# 2022-08-30 13:35:00
# 2022-08-30 14:05:00
# 2022-08-30 14:35:00
# 2022-08-31 09:35:00
# 2022-08-31 10:05:00
# 2022-08-31 10:35:00
# 2022-08-31 11:05:00
# 2022-08-31 13:05:00
# 2022-08-31 13:35:00
# 2022-08-31 14:05:00
# 2022-08-31 14:35:00
# 2022-09-01 09:35:00
# 2022-09-01 10:05:00
# 2022-09-01 10:35:00
# 2022-09-01 11:05:00
# 2022-09-01 13:05:00
# 2022-09-01 13:35:00
# 2022-09-01 14:05:00
# 2022-09-01 14:35:00
# 2022-09-02 09:35:00
# 2022-09-02 10:05:00
# 2022-09-02 10:35:00
# 2022-09-02 11:05:00
# 2022-09-02 13:05:00
# 2022-09-02 13:35:00
# 2022-09-02 14:05:00
# 2022-09-02 14:35:00
# 2022-09-05 09:35:00
# 2022-09-05 10:05:00
# 2022-09-05 10:35:00
# 2022-09-05 11:05:00
# 2022-09-05 13:05:00
# 2022-09-05 13:35:00
# 2022-09-05 14:05:00
# 2022-09-05 14:35:00
# 2022-09-06 09:35:00
# 2022-09-06 10:05:00
# 2022-09-06 10:35:00
# 2022-09-06 11:05:00
# 2022-09-06 13:05:00
# 2022-09-06 13:35:00
# 2022-09-06 14:05:00
# 2022-09-06 14:35:00
# 2022-09-07 09:35:00
# 2022-09-07 10:05:00
# 2022-09-07 10:35:00
# 2022-09-07 11:05:00
# 2022-09-07 13:05:00
# 2022-09-07 13:35:00
# 2022-09-07 14:05:00
# 2022-09-07 14:35:00
# 2022-09-08 09:35:00
# 2022-09-08 10:05:00
# 2022-09-08 10:35:00
# 2022-09-08 11:05:00
# 2022-09-08 13:05:00
# 2022-09-08 13:35:00
# 2022-09-08 14:05:00
# 2022-09-08 14:35:00
# 2022-09-09 09:35:00
# 2022-09-09 10:05:00
# 2022-09-09 10:35:00
# 2022-09-09 11:05:00
# 2022-09-09 13:05:00
# 2022-09-09 13:35:00
# 2022-09-09 14:05:00
# 2022-09-09 14:35:00
# 2022-09-13 09:35:00
# 2022-09-13 10:05:00
# 2022-09-13 10:35:00
# 2022-09-13 11:05:00
# 2022-09-13 13:05:00
# 2022-09-13 13:35:00
# 2022-09-13 14:05:00
# 2022-09-13 14:35:00
# 2022-09-14 09:35:00
# 2022-09-14 10:05:00
# 2022-09-14 10:35:00
# 2022-09-14 11:05:00
# 2022-09-14 13:05:00
# 2022-09-14 13:35:00
# 2022-09-14 14:05:00
# 2022-09-14 14:35:00
# 2022-09-15 09:35:00
# 2022-09-15 10:05:00
# 2022-09-15 10:35:00
# 2022-09-15 11:05:00
# 2022-09-15 13:05:00
# 2022-09-15 13:35:00
# 2022-09-15 14:05:00
# 2022-09-15 14:35:00
# 2022-09-16 09:35:00
# 2022-09-16 10:05:00
# 2022-09-16 10:35:00
# 2022-09-16 11:05:00
# 2022-09-16 13:05:00
# 2022-09-16 13:35:00
# 2022-09-16 14:05:00
# 2022-09-16 14:35:00
# 2022-09-19 09:35:00
# 2022-09-19 10:05:00
# 2022-09-19 10:35:00
# 2022-09-19 11:05:00
# 2022-09-19 13:05:00
# 2022-09-19 13:35:00
# 2022-09-19 14:05:00
# 2022-09-19 14:35:00
# 2022-09-20 09:35:00
# 2022-09-20 10:05:00
# 2022-09-20 10:35:00
# 2022-09-20 11:05:00
# 2022-09-20 13:05:00
# 2022-09-20 13:35:00
# 2022-09-20 14:05:00
# 2022-09-20 14:35:00
# 2022-09-21 09:35:00
# 2022-09-21 10:05:00
# 2022-09-21 10:35:00
# 2022-09-21 11:05:00
# 2022-09-21 13:05:00
# 2022-09-21 13:35:00
# 2022-09-21 14:05:00
# 2022-09-21 14:35:00
# 2022-09-22 09:35:00
# 2022-09-22 10:05:00
# 2022-09-22 10:35:00
# 2022-09-22 11:05:00
# 2022-09-22 13:05:00
# 2022-09-22 13:35:00
# 2022-09-22 14:05:00
# 2022-09-22 14:35:00
# 2022-09-23 09:35:00
# 2022-09-23 10:05:00
# 2022-09-23 10:35:00
# 2022-09-23 11:05:00
# 2022-09-23 13:05:00
# 2022-09-23 13:35:00
# 2022-09-23 14:05:00
# 2022-09-23 14:35:00
# 2022-09-26 09:35:00
# 2022-09-26 10:05:00
# 2022-09-26 10:35:00
# 2022-09-26 11:05:00
# 2022-09-26 13:05:00
# 2022-09-26 13:35:00
# 2022-09-26 14:05:00
# 2022-09-26 14:35:00
# 2022-09-27 09:35:00
# 2022-09-27 10:05:00
# 2022-09-27 10:35:00
# 2022-09-27 11:05:00
# 2022-09-27 13:05:00
# 2022-09-27 13:35:00
# 2022-09-27 14:05:00
# 2022-09-27 14:35:00
# 2022-09-28 09:35:00
# 2022-09-28 10:05:00
# 2022-09-28 10:35:00
# 2022-09-28 11:05:00
# 2022-09-28 13:05:00
# 2022-09-28 13:35:00
# 2022-09-28 14:05:00
# 2022-09-28 14:35:00
# 2022-09-29 09:35:00
# 2022-09-29 10:05:00
# 2022-09-29 10:35:00
# 2022-09-29 11:05:00
# 2022-09-29 13:05:00
# 2022-09-29 13:35:00
# 2022-09-29 14:05:00
# 2022-09-29 14:35:00
# 2022-09-30 09:35:00
# 2022-09-30 10:05:00
# 2022-09-30 10:35:00
# 2022-09-30 11:05:00
# 2022-09-30 13:05:00
# 2022-09-30 13:35:00
# 2022-09-30 14:05:00
# 2022-09-30 14:35:00
# 2022-10-10 09:35:00
# 2022-10-10 10:05:00
# 2022-10-10 10:35:00
# 2022-10-10 11:05:00
# 2022-10-10 13:05:00
# 2022-10-10 13:35:00
# 2022-10-10 14:05:00
# 2022-10-10 14:35:00
# 2022-10-11 09:35:00
# 2022-10-11 10:05:00
# 2022-10-11 10:35:00
# 2022-10-11 11:05:00
# 2022-10-11 13:05:00
# 2022-10-11 13:35:00
# 2022-10-11 14:05:00
# 2022-10-11 14:35:00
# 2022-10-12 09:35:00
# 2022-10-12 10:05:00
# 2022-10-12 10:35:00
# 2022-10-12 11:05:00
# 2022-10-12 13:05:00
# 2022-10-12 13:35:00
# 2022-10-12 14:05:00
# 2022-10-12 14:35:00
# 2022-10-13 09:35:00
# 2022-10-13 10:05:00
# 2022-10-13 10:35:00
# 2022-10-13 11:05:00
# 2022-10-13 13:05:00
# 2022-10-13 13:35:00
# 2022-10-13 14:05:00
# 2022-10-13 14:35:00
# 2022-10-14 09:35:00
# 2022-10-14 10:05:00
# 2022-10-14 10:35:00
# 2022-10-14 11:05:00
# 2022-10-14 13:05:00
# 2022-10-14 13:35:00
# 2022-10-14 14:05:00
# 2022-10-14 14:35:00
# 2022-10-17 09:35:00
# 2022-10-17 10:05:00
# 2022-10-17 10:35:00
# 2022-10-17 11:05:00
# 2022-10-17 13:05:00
# 2022-10-17 13:35:00
# 2022-10-17 14:05:00
# 2022-10-17 14:35:00
# 2022-10-18 09:35:00
# 2022-10-18 10:05:00
# 2022-10-18 10:35:00
# 2022-10-18 11:05:00
# 2022-10-18 13:05:00
# 2022-10-18 13:35:00
# 2022-10-18 14:05:00
# 2022-10-18 14:35:00
# 2022-10-19 09:35:00
# 2022-10-19 10:05:00
# 2022-10-19 10:35:00
# 2022-10-19 11:05:00
# 2022-10-19 13:05:00
# 2022-10-19 13:35:00
# 2022-10-19 14:05:00
# 2022-10-19 14:35:00
# 2022-10-20 09:35:00
# 2022-10-20 10:05:00
# 2022-10-20 10:35:00
# 2022-10-20 11:05:00
# 2022-10-20 13:05:00
# 2022-10-20 13:35:00
# 2022-10-20 14:05:00
# 2022-10-20 14:35:00
# 2022-10-21 09:35:00
# 2022-10-21 10:05:00
# 2022-10-21 10:35:00
# 2022-10-21 11:05:00
# 2022-10-21 13:05:00
# 2022-10-21 13:35:00
# 2022-10-21 14:05:00
# 2022-10-21 14:35:00
# 2022-10-24 09:35:00
# 2022-10-24 10:05:00
# 2022-10-24 10:35:00
# 2022-10-24 11:05:00
# 2022-10-24 13:05:00
# 2022-10-24 13:35:00
# 2022-10-24 14:05:00
# 2022-10-24 14:35:00
# 2022-10-25 09:35:00
# 2022-10-25 10:05:00
# 2022-10-25 10:35:00
# 2022-10-25 11:05:00
# 2022-10-25 13:05:00
# 2022-10-25 13:35:00
# 2022-10-25 14:05:00
# 2022-10-25 14:35:00
# 2022-10-26 09:35:00
# 2022-10-26 10:05:00
# 2022-10-26 10:35:00
# 2022-10-26 11:05:00
# 2022-10-26 13:05:00
# 2022-10-26 13:35:00
# 2022-10-26 14:05:00
# 2022-10-26 14:35:00
# 2022-10-27 09:35:00
# 2022-10-27 10:05:00
# 2022-10-27 10:35:00
# 2022-10-27 11:05:00
# 2022-10-27 13:05:00
# 2022-10-27 13:35:00
# 2022-10-27 14:05:00
# 2022-10-27 14:35:00
# 2022-10-28 09:35:00
# 2022-10-28 10:05:00
# 2022-10-28 10:35:00
# 2022-10-28 11:05:00
# 2022-10-28 13:05:00
# 2022-10-28 13:35:00
# 2022-10-28 14:05:00
# 2022-10-28 14:35:00
# 2022-10-31 09:35:00
# 2022-10-31 10:05:00
# 2022-10-31 10:35:00
# 2022-10-31 11:05:00
# 2022-10-31 13:05:00
# 2022-10-31 13:35:00
# 2022-10-31 14:05:00
# 2022-10-31 14:35:00
# 2022-11-01 09:35:00
# 2022-11-01 10:05:00
# 2022-11-01 10:35:00
# 2022-11-01 11:05:00
# 2022-11-01 13:05:00
# 2022-11-01 13:35:00
# 2022-11-01 14:05:00
# 2022-11-01 14:35:00
# 2022-11-02 09:35:00
# 2022-11-02 10:05:00
# 2022-11-02 10:35:00
# 2022-11-02 11:05:00
# 2022-11-02 13:05:00
# 2022-11-02 13:35:00
# 2022-11-02 14:05:00
# 2022-11-02 14:35:00
# 2022-11-03 09:35:00
# 2022-11-03 10:05:00
# 2022-11-03 10:35:00
# 2022-11-03 11:05:00
# 2022-11-03 13:05:00
# 2022-11-03 13:35:00
# 2022-11-03 14:05:00
# 2022-11-03 14:35:00
# 2022-11-04 09:35:00
# 2022-11-04 10:05:00
# 2022-11-04 10:35:00
# 2022-11-04 11:05:00
# 2022-11-04 13:05:00
# 2022-11-04 13:35:00
# 2022-11-04 14:05:00
# 2022-11-04 14:35:00
# 2022-11-07 09:35:00
# 2022-11-07 10:05:00
# 2022-11-07 10:35:00
# 2022-11-07 11:05:00
# 2022-11-07 13:05:00
# 2022-11-07 13:35:00
# 2022-11-07 14:05:00
# 2022-11-07 14:35:00
# 2022-11-08 09:35:00
# 2022-11-08 10:05:00
# 2022-11-08 10:35:00
# 2022-11-08 11:05:00
# 2022-11-08 13:05:00
# 2022-11-08 13:35:00
# 2022-11-08 14:05:00
# 2022-11-08 14:35:00
# 2022-11-09 09:35:00
# 2022-11-09 10:05:00
# 2022-11-09 10:35:00
# 2022-11-09 11:05:00
# 2022-11-09 13:05:00
# 2022-11-09 13:35:00
# 2022-11-09 14:05:00
# 2022-11-09 14:35:00
# 2022-11-10 09:35:00
# 2022-11-10 10:05:00
# 2022-11-10 10:35:00
# 2022-11-10 11:05:00
# 2022-11-10 13:05:00
# 2022-11-10 13:35:00
# 2022-11-10 14:05:00
# 2022-11-10 14:35:00
# 2022-11-11 09:35:00
# 2022-11-11 10:05:00
# 2022-11-11 10:35:00
# 2022-11-11 11:05:00
# 2022-11-11 13:05:00
# 2022-11-11 13:35:00
# 2022-11-11 14:05:00
# 2022-11-11 14:35:00
# 2022-11-14 09:35:00
# 2022-11-14 10:05:00
# 2022-11-14 10:35:00
# 2022-11-14 11:05:00
# 2022-11-14 13:05:00
# 2022-11-14 13:35:00
# 2022-11-14 14:05:00
# 2022-11-14 14:35:00
# 2022-11-15 09:35:00
# 2022-11-15 10:05:00
# 2022-11-15 10:35:00
# 2022-11-15 11:05:00
# 2022-11-15 13:05:00
# 2022-11-15 13:35:00
# 2022-11-15 14:05:00
# 2022-11-15 14:35:00
# 2022-11-16 09:35:00
# 2022-11-16 10:05:00
# 2022-11-16 10:35:00
# 2022-11-16 11:05:00
# 2022-11-16 13:05:00
# 2022-11-16 13:35:00
# 2022-11-16 14:05:00
# 2022-11-16 14:35:00
# 2022-11-17 09:35:00
# 2022-11-17 10:05:00
# 2022-11-17 10:35:00
# 2022-11-17 11:05:00
# 2022-11-17 13:05:00
# 2022-11-17 13:35:00
# 2022-11-17 14:05:00
# 2022-11-17 14:35:00
# 2022-11-18 09:35:00
# 2022-11-18 10:05:00
# 2022-11-18 10:35:00
# 2022-11-18 11:05:00
# 2022-11-18 13:05:00
# 2022-11-18 13:35:00
# 2022-11-18 14:05:00
# 2022-11-18 14:35:00
# 2022-11-21 09:35:00
# 2022-11-21 10:05:00
# 2022-11-21 10:35:00
# 2022-11-21 11:05:00
# 2022-11-21 13:05:00
# 2022-11-21 13:35:00
# 2022-11-21 14:05:00
# 2022-11-21 14:35:00
# 2022-11-22 09:35:00
# 2022-11-22 10:05:00
# 2022-11-22 10:35:00
# 2022-11-22 11:05:00
# 2022-11-22 13:05:00
# 2022-11-22 13:35:00
# 2022-11-22 14:05:00
# 2022-11-22 14:35:00
# 2022-11-23 09:35:00
# 2022-11-23 10:05:00
# 2022-11-23 10:35:00
# 2022-11-23 11:05:00
# 2022-11-23 13:05:00
# 2022-11-23 13:35:00
# 2022-11-23 14:05:00
# 2022-11-23 14:35:00
# 2022-11-24 09:35:00
# 2022-11-24 10:05:00
# 2022-11-24 10:35:00
# 2022-11-24 11:05:00
# 2022-11-24 13:05:00
# 2022-11-24 13:35:00
# 2022-11-24 14:05:00
# 2022-11-24 14:35:00
# 2022-11-25 09:35:00
# 2022-11-25 10:05:00
# 2022-11-25 10:35:00
# 2022-11-25 11:05:00
# 2022-11-25 13:05:00
# 2022-11-25 13:35:00
# 2022-11-25 14:05:00
# 2022-11-25 14:35:00
# 2022-11-28 09:35:00
# 2022-11-28 10:05:00
# 2022-11-28 10:35:00
# 2022-11-28 11:05:00
# 2022-11-28 13:05:00
# 2022-11-28 13:35:00
# 2022-11-28 14:05:00
# 2022-11-28 14:35:00
# 2022-11-29 09:35:00
# 2022-11-29 10:05:00
# 2022-11-29 10:35:00
# 2022-11-29 11:05:00
# 2022-11-29 13:05:00
# 2022-11-29 13:35:00
# 2022-11-29 14:05:00
# 2022-11-29 14:35:00
# 2022-11-30 09:35:00
# 2022-11-30 10:05:00
# 2022-11-30 10:35:00
# 2022-11-30 11:05:00
# 2022-11-30 13:05:00
# 2022-11-30 13:35:00
# 2022-11-30 14:05:00
# 2022-11-30 14:35:00
# 2022-12-01 09:35:00
# 2022-12-01 10:05:00
# 2022-12-01 10:35:00
# 2022-12-01 11:05:00
# 2022-12-01 13:05:00
# 2022-12-01 13:35:00
# 2022-12-01 14:05:00
# 2022-12-01 14:35:00
# 2022-12-02 09:35:00
# 2022-12-02 10:05:00
# 2022-12-02 10:35:00
# 2022-12-02 11:05:00
# 2022-12-02 13:05:00
# 2022-12-02 13:35:00
# 2022-12-02 14:05:00
# 2022-12-02 14:35:00
# 2022-12-05 09:35:00
# 2022-12-05 10:05:00
# 2022-12-05 10:35:00
# 2022-12-05 11:05:00
# 2022-12-05 13:05:00
# 2022-12-05 13:35:00
# 2022-12-05 14:05:00
# 2022-12-05 14:35:00
# 2022-12-06 09:35:00
# 2022-12-06 10:05:00
# 2022-12-06 10:35:00
# 2022-12-06 11:05:00
# 2022-12-06 13:05:00
# 2022-12-06 13:35:00
# 2022-12-06 14:05:00
# 2022-12-06 14:35:00
# 2022-12-07 09:35:00
# 2022-12-07 10:05:00
# 2022-12-07 10:35:00
# 2022-12-07 11:05:00
# 2022-12-07 13:05:00
# 2022-12-07 13:35:00
# 2022-12-07 14:05:00
# 2022-12-07 14:35:00
# 2022-12-08 09:35:00
# 2022-12-08 10:05:00
# 2022-12-08 10:35:00
# 2022-12-08 11:05:00
# 2022-12-08 13:05:00
# 2022-12-08 13:35:00
# 2022-12-08 14:05:00
# 2022-12-08 14:35:00
# 2022-12-09 09:35:00
# 2022-12-09 10:05:00
# 2022-12-09 10:35:00
# 2022-12-09 11:05:00
# 2022-12-09 13:05:00
# 2022-12-09 13:35:00
# 2022-12-09 14:05:00
# 2022-12-09 14:35:00
# 2022-12-12 09:35:00
# 2022-12-12 10:05:00
# 2022-12-12 10:35:00
# 2022-12-12 11:05:00
# 2022-12-12 13:05:00
# 2022-12-12 13:35:00
# 2022-12-12 14:05:00
# 2022-12-12 14:35:00
# 2022-12-13 09:35:00
# 2022-12-13 10:05:00
# 2022-12-13 10:35:00
# 2022-12-13 11:05:00
# 2022-12-13 13:05:00
# 2022-12-13 13:35:00
# 2022-12-13 14:05:00
# 2022-12-13 14:35:00
# 2022-12-14 09:35:00
# 2022-12-14 10:05:00
# 2022-12-14 10:35:00
# 2022-12-14 11:05:00
# 2022-12-14 13:05:00
# 2022-12-14 13:35:00
# 2022-12-14 14:05:00
# 2022-12-14 14:35:00
# 2022-12-15 09:35:00
# 2022-12-15 10:05:00
# 2022-12-15 10:35:00
# 2022-12-15 11:05:00
# 2022-12-15 13:05:00
# 2022-12-15 13:35:00
# 2022-12-15 14:05:00
# 2022-12-15 14:35:00
# 2022-12-16 09:35:00
# 2022-12-16 10:05:00
# 2022-12-16 10:35:00
# 2022-12-16 11:05:00
# 2022-12-16 13:05:00
# 2022-12-16 13:35:00
# 2022-12-16 14:05:00
# 2022-12-16 14:35:00
# 2022-12-19 09:35:00
# 2022-12-19 10:05:00
# 2022-12-19 10:35:00
# 2022-12-19 11:05:00
# 2022-12-19 13:05:00
# 2022-12-19 13:35:00
# 2022-12-19 14:05:00
# 2022-12-19 14:35:00
# 2022-12-20 09:35:00
# 2022-12-20 10:05:00
# 2022-12-20 10:35:00
# 2022-12-20 11:05:00
# 2022-12-20 13:05:00
# 2022-12-20 13:35:00
# 2022-12-20 14:05:00
# 2022-12-20 14:35:00
# 2022-12-21 09:35:00
# 2022-12-21 10:05:00
# 2022-12-21 10:35:00
# 2022-12-21 11:05:00
# 2022-12-21 13:05:00
# 2022-12-21 13:35:00
# 2022-12-21 14:05:00
# 2022-12-21 14:35:00
# 2022-12-22 09:35:00
# 2022-12-22 10:05:00
# 2022-12-22 10:35:00
# 2022-12-22 11:05:00
# 2022-12-22 13:05:00
# 2022-12-22 13:35:00
# 2022-12-22 14:05:00
# 2022-12-22 14:35:00
# 2022-12-23 09:35:00
# 2022-12-23 10:05:00
# 2022-12-23 10:35:00
# 2022-12-23 11:05:00
# 2022-12-23 13:05:00
# 2022-12-23 13:35:00
# 2022-12-23 14:05:00
# 2022-12-23 14:35:00
# 2022-12-26 09:35:00
# 2022-12-26 10:05:00
# 2022-12-26 10:35:00
# 2022-12-26 11:05:00
# 2022-12-26 13:05:00
# 2022-12-26 13:35:00
# 2022-12-26 14:05:00
# 2022-12-26 14:35:00
# 2022-12-27 09:35:00
# 2022-12-27 10:05:00
# 2022-12-27 10:35:00
# 2022-12-27 11:05:00
# 2022-12-27 13:05:00
# 2022-12-27 13:35:00
# 2022-12-27 14:05:00
# 2022-12-27 14:35:00
# 2022-12-28 09:35:00
# 2022-12-28 10:05:00
# 2022-12-28 10:35:00
# 2022-12-28 11:05:00
# 2022-12-28 13:05:00
# 2022-12-28 13:35:00
# 2022-12-28 14:05:00
# 2022-12-28 14:35:00
# 2022-12-29 09:35:00
# 2022-12-29 10:05:00
# 2022-12-29 10:35:00
# 2022-12-29 11:05:00
# 2022-12-29 13:05:00
# 2022-12-29 13:35:00
# 2022-12-29 14:05:00
# 2022-12-29 14:35:00
# 2022-12-30 09:35:00
# 2022-12-30 10:05:00
# 2022-12-30 10:35:00
# 2022-12-30 11:05:00
# 2022-12-30 13:05:00
# 2022-12-30 13:35:00
# 2022-12-30 14:05:00
# 2022-12-30 14:35:00
# 2023-01-03 09:35:00
# 2023-01-03 10:05:00
# 2023-01-03 10:35:00
# 2023-01-03 11:05:00
# 2023-01-03 13:05:00
# 2023-01-03 13:35:00
# 2023-01-03 14:05:00
# 2023-01-03 14:35:00
# 2023-01-04 09:35:00
# 2023-01-04 10:05:00
# 2023-01-04 10:35:00
# 2023-01-04 11:05:00
# 2023-01-04 13:05:00
# 2023-01-04 13:35:00
# 2023-01-04 14:05:00
# 2023-01-04 14:35:00
# 2023-01-05 09:35:00
# 2023-01-05 10:05:00
# 2023-01-05 10:35:00
# 2023-01-05 11:05:00
# 2023-01-05 13:05:00
# 2023-01-05 13:35:00
# 2023-01-05 14:05:00
# 2023-01-05 14:35:00
# 2023-01-06 09:35:00
# 2023-01-06 10:05:00
# 2023-01-06 10:35:00
# 2023-01-06 11:05:00
# 2023-01-06 13:05:00
# 2023-01-06 13:35:00
# 2023-01-06 14:05:00
# 2023-01-06 14:35:00
# 2023-01-09 09:35:00
# 2023-01-09 10:05:00
# 2023-01-09 10:35:00
# 2023-01-09 11:05:00
# 2023-01-09 13:05:00
# 2023-01-09 13:35:00
# 2023-01-09 14:05:00
# 2023-01-09 14:35:00
# 2023-01-10 09:35:00
# 2023-01-10 10:05:00
# 2023-01-10 10:35:00
# 2023-01-10 11:05:00
# 2023-01-10 13:05:00
# 2023-01-10 13:35:00
# 2023-01-10 14:05:00
# 2023-01-10 14:35:00
# 2023-01-11 09:35:00
# 2023-01-11 10:05:00
# 2023-01-11 10:35:00
# 2023-01-11 11:05:00
# 2023-01-11 13:05:00
# 2023-01-11 13:35:00
# 2023-01-11 14:05:00
# 2023-01-11 14:35:00
# 2023-01-12 09:35:00
# 2023-01-12 10:05:00
# 2023-01-12 10:35:00
# 2023-01-12 11:05:00
# 2023-01-12 13:05:00
# 2023-01-12 13:35:00
# 2023-01-12 14:05:00
# 2023-01-12 14:35:00
# 2023-01-13 09:35:00
# 2023-01-13 10:05:00
# 2023-01-13 10:35:00
# 2023-01-13 11:05:00
# 2023-01-13 13:05:00
# 2023-01-13 13:35:00
# 2023-01-13 14:05:00
# 2023-01-13 14:35:00
# 2023-01-16 09:35:00
# 2023-01-16 10:05:00
# 2023-01-16 10:35:00
# 2023-01-16 11:05:00
# 2023-01-16 13:05:00
# 2023-01-16 13:35:00
# 2023-01-16 14:05:00
# 2023-01-16 14:35:00
# 2023-01-17 09:35:00
# 2023-01-17 10:05:00
# 2023-01-17 10:35:00
# 2023-01-17 11:05:00
# 2023-01-17 13:05:00
# 2023-01-17 13:35:00
# 2023-01-17 14:05:00
# 2023-01-17 14:35:00
# 2023-01-18 09:35:00
# 2023-01-18 10:05:00
# 2023-01-18 10:35:00
# 2023-01-18 11:05:00
# 2023-01-18 13:05:00
# 2023-01-18 13:35:00
# 2023-01-18 14:05:00
# 2023-01-18 14:35:00
# 2023-01-19 09:35:00
# 2023-01-19 10:05:00
# 2023-01-19 10:35:00
# 2023-01-19 11:05:00
# 2023-01-19 13:05:00
# 2023-01-19 13:35:00
# 2023-01-19 14:05:00
# 2023-01-19 14:35:00
# 2023-01-20 09:35:00
# 2023-01-20 10:05:00
# 2023-01-20 10:35:00
# 2023-01-20 11:05:00
# 2023-01-20 13:05:00
# 2023-01-20 13:35:00
# 2023-01-20 14:05:00
# 2023-01-20 14:35:00
# 2023-01-30 09:35:00
# 2023-01-30 10:05:00
# 2023-01-30 10:35:00
# 2023-01-30 11:05:00
# 2023-01-30 13:05:00
# 2023-01-30 13:35:00
# 2023-01-30 14:05:00
# 2023-01-30 14:35:00
# 2023-01-31 09:35:00
# 2023-01-31 10:05:00
# 2023-01-31 10:35:00
# 2023-01-31 11:05:00
# 2023-01-31 13:05:00
# 2023-01-31 13:35:00
# 2023-01-31 14:05:00
# 2023-01-31 14:35:00
# 2023-02-01 09:35:00
# 2023-02-01 10:05:00
# 2023-02-01 10:35:00
# 2023-02-01 11:05:00
# 2023-02-01 13:05:00
# 2023-02-01 13:35:00
# 2023-02-01 14:05:00
# 2023-02-01 14:35:00
# 2023-02-02 09:35:00
# 2023-02-02 10:05:00
# 2023-02-02 10:35:00
# 2023-02-02 11:05:00
# 2023-02-02 13:05:00
# 2023-02-02 13:35:00
# 2023-02-02 14:05:00
# 2023-02-02 14:35:00
# 2023-02-03 09:35:00
# 2023-02-03 10:05:00
# 2023-02-03 10:35:00
# 2023-02-03 11:05:00
# 2023-02-03 13:05:00
# 2023-02-03 13:35:00
# 2023-02-03 14:05:00
# 2023-02-03 14:35:00
# 2023-02-06 09:35:00
# 2023-02-06 10:05:00
# 2023-02-06 10:35:00
# 2023-02-06 11:05:00
# 2023-02-06 13:05:00
# 2023-02-06 13:35:00
# 2023-02-06 14:05:00
# 2023-02-06 14:35:00
# 2023-02-07 09:35:00
# 2023-02-07 10:05:00
# 2023-02-07 10:35:00
# 2023-02-07 11:05:00
# 2023-02-07 13:05:00
# 2023-02-07 13:35:00
# 2023-02-07 14:05:00
# 2023-02-07 14:35:00
# 2023-02-08 09:35:00
# 2023-02-08 10:05:00
# 2023-02-08 10:35:00
# 2023-02-08 11:05:00
# 2023-02-08 13:05:00
# 2023-02-08 13:35:00
# 2023-02-08 14:05:00
# 2023-02-08 14:35:00
# 2023-02-09 09:35:00
# 2023-02-09 10:05:00
# 2023-02-09 10:35:00
# 2023-02-09 11:05:00
# 2023-02-09 13:05:00
# 2023-02-09 13:35:00
# 2023-02-09 14:05:00
# 2023-02-09 14:35:00
# 2023-02-10 09:35:00
# 2023-02-10 10:05:00
# 2023-02-10 10:35:00
# 2023-02-10 11:05:00
# 2023-02-10 13:05:00
# 2023-02-10 13:35:00
# 2023-02-10 14:05:00
# 2023-02-10 14:35:00
# 2023-02-13 09:35:00
# 2023-02-13 10:05:00
# 2023-02-13 10:35:00
# 2023-02-13 11:05:00
# 2023-02-13 13:05:00
# 2023-02-13 13:35:00
# 2023-02-13 14:05:00
# 2023-02-13 14:35:00
# 2023-02-14 09:35:00
# 2023-02-14 10:05:00
# 2023-02-14 10:35:00
# 2023-02-14 11:05:00
# 2023-02-14 13:05:00
# 2023-02-14 13:35:00
# 2023-02-14 14:05:00
# 2023-02-14 14:35:00
# 2023-02-15 09:35:00
# 2023-02-15 10:05:00
# 2023-02-15 10:35:00
# 2023-02-15 11:05:00
# 2023-02-15 13:05:00
# 2023-02-15 13:35:00
# 2023-02-15 14:05:00
# 2023-02-15 14:35:00
# 2023-02-16 09:35:00
# 2023-02-16 10:05:00
# 2023-02-16 10:35:00
# 2023-02-16 11:05:00
# 2023-02-16 13:05:00
# 2023-02-16 13:35:00
# 2023-02-16 14:05:00
# 2023-02-16 14:35:00
# 2023-02-17 09:35:00
# 2023-02-17 10:05:00
# 2023-02-17 10:35:00
# 2023-02-17 11:05:00
# 2023-02-17 13:05:00
# 2023-02-17 13:35:00
# 2023-02-17 14:05:00
# 2023-02-17 14:35:00
# 2023-02-20 09:35:00
# 2023-02-20 10:05:00
# 2023-02-20 10:35:00
# 2023-02-20 11:05:00
# 2023-02-20 13:05:00
# 2023-02-20 13:35:00
# 2023-02-20 14:05:00
# 2023-02-20 14:35:00
# 2023-02-21 09:35:00
# 2023-02-21 10:05:00
# 2023-02-21 10:35:00
# 2023-02-21 11:05:00
# 2023-02-21 13:05:00
# 2023-02-21 13:35:00
# 2023-02-21 14:05:00
# 2023-02-21 14:35:00
# 2023-02-22 09:35:00
# 2023-02-22 10:05:00
# 2023-02-22 10:35:00
# 2023-02-22 11:05:00
# 2023-02-22 13:05:00
# 2023-02-22 13:35:00
# 2023-02-22 14:05:00
# 2023-02-22 14:35:00
# 2023-02-23 09:35:00
# 2023-02-23 10:05:00
# 2023-02-23 10:35:00
# 2023-02-23 11:05:00
# 2023-02-23 13:05:00
# 2023-02-23 13:35:00
# 2023-02-23 14:05:00
# 2023-02-23 14:35:00
# 2023-02-24 09:35:00
# 2023-02-24 10:05:00
# 2023-02-24 10:35:00
# 2023-02-24 11:05:00
# 2023-02-24 13:05:00
# 2023-02-24 13:35:00
# 2023-02-24 14:05:00
# 2023-02-24 14:35:00
# 2023-02-27 09:35:00
# 2023-02-27 10:05:00
# 2023-02-27 10:35:00
# 2023-02-27 11:05:00
# 2023-02-27 13:05:00
# 2023-02-27 13:35:00
# 2023-02-27 14:05:00
# 2023-02-27 14:35:00
# 2023-02-28 09:35:00
# 2023-02-28 10:05:00
# 2023-02-28 10:35:00
# 2023-02-28 11:05:00
# 2023-02-28 13:05:00
# 2023-02-28 13:35:00
# 2023-02-28 14:05:00
# 2023-02-28 14:35:00
# 2023-03-01 09:35:00
# 2023-03-01 10:05:00
# 2023-03-01 10:35:00
# 2023-03-01 11:05:00
# 2023-03-01 13:05:00
# 2023-03-01 13:35:00
# 2023-03-01 14:05:00
# 2023-03-01 14:35:00
# 2023-03-02 09:35:00
# 2023-03-02 10:05:00
# 2023-03-02 10:35:00
# 2023-03-02 11:05:00
# 2023-03-02 13:05:00
# 2023-03-02 13:35:00
# 2023-03-02 14:05:00
# 2023-03-02 14:35:00
# 2023-03-03 09:35:00
# 2023-03-03 10:05:00
# 2023-03-03 10:35:00
# 2023-03-03 11:05:00
# 2023-03-03 13:05:00
# 2023-03-03 13:35:00
# 2023-03-03 14:05:00
# 2023-03-03 14:35:00
# 2023-03-06 09:35:00
# 2023-03-06 10:05:00
# 2023-03-06 10:35:00
# 2023-03-06 11:05:00
# 2023-03-06 13:05:00
# 2023-03-06 13:35:00
# 2023-03-06 14:05:00
# 2023-03-06 14:35:00
# 2023-03-07 09:35:00
# 2023-03-07 10:05:00
# 2023-03-07 10:35:00
# 2023-03-07 11:05:00
# 2023-03-07 13:05:00
# 2023-03-07 13:35:00
# 2023-03-07 14:05:00
# 2023-03-07 14:35:00
# 2023-03-08 09:35:00
# 2023-03-08 10:05:00
# 2023-03-08 10:35:00
# 2023-03-08 11:05:00
# 2023-03-08 13:05:00
# 2023-03-08 13:35:00
# 2023-03-08 14:05:00
# 2023-03-08 14:35:00
# 2023-03-09 09:35:00
# 2023-03-09 10:05:00
# 2023-03-09 10:35:00
# 2023-03-09 11:05:00
# 2023-03-09 13:05:00
# 2023-03-09 13:35:00
# 2023-03-09 14:05:00
# 2023-03-09 14:35:00
# 2023-03-10 09:35:00
# 2023-03-10 10:05:00
# 2023-03-10 10:35:00
# 2023-03-10 11:05:00
# 2023-03-10 13:05:00
# 2023-03-10 13:35:00
# 2023-03-10 14:05:00
# 2023-03-10 14:35:00
# 2023-03-13 09:35:00
# 2023-03-13 10:05:00
# 2023-03-13 10:35:00
# 2023-03-13 11:05:00
# 2023-03-13 13:05:00
# 2023-03-13 13:35:00
# 2023-03-13 14:05:00
# 2023-03-13 14:35:00
# 2023-03-14 09:35:00
# 2023-03-14 10:05:00
# 2023-03-14 10:35:00
# 2023-03-14 11:05:00
# 2023-03-14 13:05:00
# 2023-03-14 13:35:00
# 2023-03-14 14:05:00
# 2023-03-14 14:35:00
# 2023-03-15 09:35:00
# 2023-03-15 10:05:00
# 2023-03-15 10:35:00
# 2023-03-15 11:05:00
# 2023-03-15 13:05:00
# 2023-03-15 13:35:00
# 2023-03-15 14:05:00
# 2023-03-15 14:35:00
# 2023-03-16 09:35:00
# 2023-03-16 10:05:00
# 2023-03-16 10:35:00
# 2023-03-16 11:05:00
# 2023-03-16 13:05:00
# 2023-03-16 13:35:00
# 2023-03-16 14:05:00
# 2023-03-16 14:35:00
# 2023-03-17 09:35:00
# 2023-03-17 10:05:00
# 2023-03-17 10:35:00
# 2023-03-17 11:05:00
# 2023-03-17 13:05:00
# 2023-03-17 13:35:00
# 2023-03-17 14:05:00
# 2023-03-17 14:35:00
# 2023-03-20 09:35:00
# 2023-03-20 10:05:00
# 2023-03-20 10:35:00
# 2023-03-20 11:05:00
# 2023-03-20 13:05:00
# 2023-03-20 13:35:00
# 2023-03-20 14:05:00
# 2023-03-20 14:35:00
# 2023-03-21 09:35:00
# 2023-03-21 10:05:00
# 2023-03-21 10:35:00
# 2023-03-21 11:05:00
# 2023-03-21 13:05:00
# 2023-03-21 13:35:00
# 2023-03-21 14:05:00
# 2023-03-21 14:35:00
# 2023-03-22 09:35:00
# 2023-03-22 10:05:00
# 2023-03-22 10:35:00
# 2023-03-22 11:05:00
# 2023-03-22 13:05:00
# 2023-03-22 13:35:00
# 2023-03-22 14:05:00
# 2023-03-22 14:35:00
# 2023-03-23 09:35:00
# 2023-03-23 10:05:00
# 2023-03-23 10:35:00
# 2023-03-23 11:05:00
# 2023-03-23 13:05:00
# 2023-03-23 13:35:00
# 2023-03-23 14:05:00
# 2023-03-23 14:35:00
# 2023-03-24 09:35:00
# 2023-03-24 10:05:00
# 2023-03-24 10:35:00
# 2023-03-24 11:05:00
# 2023-03-24 13:05:00
# 2023-03-24 13:35:00
# 2023-03-24 14:05:00
# 2023-03-24 14:35:00
# 2023-03-27 09:35:00
# 2023-03-27 10:05:00
# 2023-03-27 10:35:00
# 2023-03-27 11:05:00
# 2023-03-27 13:05:00
# 2023-03-27 13:35:00
# 2023-03-27 14:05:00
# 2023-03-27 14:35:00
# 2023-03-28 09:35:00
# 2023-03-28 10:05:00
# 2023-03-28 10:35:00
# 2023-03-28 11:05:00
# 2023-03-28 13:05:00
# 2023-03-28 13:35:00
# 2023-03-28 14:05:00
# 2023-03-28 14:35:00
# 2023-03-29 09:35:00
# 2023-03-29 10:05:00
# 2023-03-29 10:35:00
# 2023-03-29 11:05:00
# 2023-03-29 13:05:00
# 2023-03-29 13:35:00
# 2023-03-29 14:05:00
# 2023-03-29 14:35:00
# 2023-03-30 09:35:00
# 2023-03-30 10:05:00
# 2023-03-30 10:35:00
# 2023-03-30 11:05:00
# 2023-03-30 13:05:00
# 2023-03-30 13:35:00
# 2023-03-30 14:05:00
# 2023-03-30 14:35:00
# 2023-03-31 09:35:00
# 2023-03-31 10:05:00
# 2023-03-31 10:35:00
# 2023-03-31 11:05:00
# 2023-03-31 13:05:00
# 2023-03-31 13:35:00
# 2023-03-31 14:05:00
# 2023-03-31 14:35:00
# 2023-04-03 09:35:00
# 2023-04-03 10:05:00
# 2023-04-03 10:35:00
# 2023-04-03 11:05:00
# 2023-04-03 13:05:00
# 2023-04-03 13:35:00
# 2023-04-03 14:05:00
# 2023-04-03 14:35:00
# 2023-04-04 09:35:00
# 2023-04-04 10:05:00
# 2023-04-04 10:35:00
# 2023-04-04 11:05:00
# 2023-04-04 13:05:00
# 2023-04-04 13:35:00
# 2023-04-04 14:05:00
# 2023-04-04 14:35:00
# 2023-04-06 09:35:00
# 2023-04-06 10:05:00
# 2023-04-06 10:35:00
# 2023-04-06 11:05:00
# 2023-04-06 13:05:00
# 2023-04-06 13:35:00
# 2023-04-06 14:05:00
# 2023-04-06 14:35:00
# 2023-04-07 09:35:00
# 2023-04-07 10:05:00
# 2023-04-07 10:35:00
# 2023-04-07 11:05:00
# 2023-04-07 13:05:00
# 2023-04-07 13:35:00
# 2023-04-07 14:05:00
# 2023-04-07 14:35:00
# 2023-04-10 09:35:00
# 2023-04-10 10:05:00
# 2023-04-10 10:35:00
# 2023-04-10 11:05:00
# 2023-04-10 13:05:00
# 2023-04-10 13:35:00
# 2023-04-10 14:05:00
# 2023-04-10 14:35:00
# 2023-04-11 09:35:00
# 2023-04-11 10:05:00
# 2023-04-11 10:35:00
# 2023-04-11 11:05:00
# 2023-04-11 13:05:00
# 2023-04-11 13:35:00
# 2023-04-11 14:05:00
# 2023-04-11 14:35:00
# 2023-04-12 09:35:00
# 2023-04-12 10:05:00
# 2023-04-12 10:35:00
# 2023-04-12 11:05:00
# 2023-04-12 13:05:00
# 2023-04-12 13:35:00
# 2023-04-12 14:05:00
# 2023-04-12 14:35:00
# 2023-04-13 09:35:00
# 2023-04-13 10:05:00
# 2023-04-13 10:35:00
# 2023-04-13 11:05:00
# 2023-04-13 13:05:00
# 2023-04-13 13:35:00
# 2023-04-13 14:05:00
# 2023-04-13 14:35:00
# 2023-04-14 09:35:00
# 2023-04-14 10:05:00
# 2023-04-14 10:35:00
# 2023-04-14 11:05:00
# 2023-04-14 13:05:00
# 2023-04-14 13:35:00
# 2023-04-14 14:05:00
# 2023-04-14 14:35:00
# 2023-04-17 09:35:00
# 2023-04-17 10:05:00
# 2023-04-17 10:35:00
# 2023-04-17 11:05:00
# 2023-04-17 13:05:00
# 2023-04-17 13:35:00
# 2023-04-17 14:05:00
# 2023-04-17 14:35:00
# 2023-04-18 09:35:00
# 2023-04-18 10:05:00
# 2023-04-18 10:35:00
# 2023-04-18 11:05:00
# 2023-04-18 13:05:00
# 2023-04-18 13:35:00
# 2023-04-18 14:05:00
# 2023-04-18 14:35:00
# 2023-04-19 09:35:00
# 2023-04-19 10:05:00
# 2023-04-19 10:35:00
# 2023-04-19 11:05:00
# 2023-04-19 13:05:00
# 2023-04-19 13:35:00
# 2023-04-19 14:05:00
# 2023-04-19 14:35:00
# 2023-04-20 09:35:00
# 2023-04-20 10:05:00
# 2023-04-20 10:35:00
# 2023-04-20 11:05:00
# 2023-04-20 13:05:00
# 2023-04-20 13:35:00
# 2023-04-20 14:05:00
# 2023-04-20 14:35:00
# 2023-04-21 09:35:00
# 2023-04-21 10:05:00
# 2023-04-21 10:35:00
# 2023-04-21 11:05:00
# 2023-04-21 13:05:00
# 2023-04-21 13:35:00
# 2023-04-21 14:05:00
# 2023-04-21 14:35:00
# 2023-04-24 09:35:00
# 2023-04-24 10:05:00
# 2023-04-24 10:35:00
# 2023-04-24 11:05:00
# 2023-04-24 13:05:00
# 2023-04-24 13:35:00
# 2023-04-24 14:05:00
# 2023-04-24 14:35:00
# 2023-04-25 09:35:00
# 2023-04-25 10:05:00
# 2023-04-25 10:35:00
# 2023-04-25 11:05:00
# 2023-04-25 13:05:00
# 2023-04-25 13:35:00
# 2023-04-25 14:05:00
# 2023-04-25 14:35:00
# 2023-04-26 09:35:00
# 2023-04-26 10:05:00
# 2023-04-26 10:35:00
# 2023-04-26 11:05:00
# 2023-04-26 13:05:00
# 2023-04-26 13:35:00
# 2023-04-26 14:05:00
# 2023-04-26 14:35:00
# 2023-04-27 09:35:00
# 2023-04-27 10:05:00
# 2023-04-27 10:35:00
# 2023-04-27 11:05:00
# 2023-04-27 13:05:00
# 2023-04-27 13:35:00
# 2023-04-27 14:05:00
# 2023-04-27 14:35:00
# 2023-04-28 09:35:00
# 2023-04-28 10:05:00
# 2023-04-28 10:35:00
# 2023-04-28 11:05:00
# 2023-04-28 13:05:00
# 2023-04-28 13:35:00
# 2023-04-28 14:05:00
# 2023-04-28 14:35:00
# 2023-05-04 09:35:00
# 2023-05-04 10:05:00
# 2023-05-04 10:35:00
# 2023-05-04 11:05:00
# 2023-05-04 13:05:00
# 2023-05-04 13:35:00
# 2023-05-04 14:05:00
# 2023-05-04 14:35:00
# 2023-05-05 09:35:00
# 2023-05-05 10:05:00
# 2023-05-05 10:35:00
# 2023-05-05 11:05:00
# 2023-05-05 13:05:00
# 2023-05-05 13:35:00
# 2023-05-05 14:05:00
# 2023-05-05 14:35:00
# 2023-05-08 09:35:00
# 2023-05-08 10:05:00
# 2023-05-08 10:35:00
# 2023-05-08 11:05:00
# 2023-05-08 13:05:00
# 2023-05-08 13:35:00
# 2023-05-08 14:05:00
# 2023-05-08 14:35:00
# 2023-05-09 09:35:00
# 2023-05-09 10:05:00
# 2023-05-09 10:35:00
# 2023-05-09 11:05:00
# 2023-05-09 13:05:00
# 2023-05-09 13:35:00
# 2023-05-09 14:05:00
# 2023-05-09 14:35:00
# 2023-05-10 09:35:00
# 2023-05-10 10:05:00
# 2023-05-10 10:35:00
# 2023-05-10 11:05:00
# 2023-05-10 13:05:00
# 2023-05-10 13:35:00
# 2023-05-10 14:05:00
# 2023-05-10 14:35:00
# 2023-05-11 09:35:00
# 2023-05-11 10:05:00
# 2023-05-11 10:35:00
# 2023-05-11 11:05:00
# 2023-05-11 13:05:00
# 2023-05-11 13:35:00
# 2023-05-11 14:05:00
# 2023-05-11 14:35:00
# 2023-05-12 09:35:00
# 2023-05-12 10:05:00
# 2023-05-12 10:35:00
# 2023-05-12 11:05:00
# 2023-05-12 13:05:00
# 2023-05-12 13:35:00
# 2023-05-12 14:05:00
# 2023-05-12 14:35:00

# %%
df_predict = pd.DataFrame(index=df_standard.loc[test_start_date:test_end_date].index[::predict_intervals])
df_predict['predict_label'] = signal_list
df_predict
# Out:
#                      predict_label
# 2022-01-04 09:35:00              1
# 2022-01-04 10:05:00              0
# 2022-01-04 10:35:00              0
# 2022-01-04 11:05:00              0
# 2022-01-04 13:05:00              0
# ...                            ...
# 2023-05-12 11:05:00              0
# 2023-05-12 13:05:00              0
# 2023-05-12 13:35:00              0
# 2023-05-12 14:05:00              0
# 2023-05-12 14:35:00              0
#
# [2616 rows x 1 columns]

# %% [markdown]
# 回测

# %%
CASH = 5000
FEE = 2.5/10000 # 单边

# %% [markdown]
# 策略评价模块

# %% [markdown]
# 策略评价指标：
#
# 年化收益率
#
# 最大回撤率
#
# 夏普比率
#
# 交易频率
#
# 胜率
#
# 盈亏比

# %%
# 计算年化收益率
def annualized_returns(cum_rets, days_per_year=365.25):
    total_rets = cum_rets.iloc[-1]
    if total_rets >= -1:
        total_days = (cum_rets.index[-1]-cum_rets.index[0]).days
        ar = round(np.power(1+total_rets, days_per_year/total_days) - 1, 4)
        return round(ar, 4)
    else:
        return -1
    
# 计算最大回撤率
def MDD(cum_rets):
    cum_values = 1 + cum_rets
    return round(max(1 - cum_values/cum_values.cummax()), 4)

# 计算交易频率，胜率和盈亏比
def win_loss_ratio(cum_rets):
    rets = cum_rets.diff().dropna()
    wins = len(rets[rets > 0])
    losses = len(rets[rets < 0])
    win_ratio = wins / (wins + losses)
    average_win = rets[rets > 0].mean()
    average_loss = rets[rets < 0].mean()
    return round((wins+losses)/len(rets), 2), round(win_ratio, 4), round(abs(average_win / average_loss), 2)

# 计算夏普比率 !!! 应该把结果转化成daily再输出策略评价指标
def sharpe_ratio(cum_rets, frequency='day', days_per_year=252, r_f=0.02):
    annualized_excess_returns = annualized_returns(cum_rets) - r_f
    rets = cum_rets.diff().dropna()
    if frequency == 'day':
        annualized_volatility = np.std(rets, ddof=1) * np.sqrt(days_per_year)
    elif frequency == '30min':
        annualized_volatility = np.std(rets, ddof=1) * np.sqrt(days_per_year*8)
    return round(annualized_excess_returns / annualized_volatility, 2)

# %%
def performance_evaluation(cum_rets):
    print('年化收益率：', annualized_returns(cum_rets))
    print('最大回撤：', MDD(cum_rets))
    print('交易频率：', win_loss_ratio(cum_rets)[0])
    print('胜率：', win_loss_ratio(cum_rets)[1])
    print('盈亏比：', win_loss_ratio(cum_rets)[2])

# %%
def trans_log(s):
    return np.exp(s) - 1

# %% [markdown]
# long only

# %%
# 仓位信息
position_list = []
position = 0
signal = 0
for i in df_predict.index[:-1]:
    # 计算信号
    if df_predict.loc[i, 'predict_label'] == 1:
        signal = 1
    elif df_predict.loc[i, 'predict_label'] == 0:
        signal = -1
    else:
        signal = 0
    
    # 计算仓位
    if position == 0 and signal == 1:
        position = 1
    elif position == 1 and signal != 1:
        position = 0
    
    position_list.append(position)
position_list.append(0)

df_position = df_predict.copy()
df_position['position'] = position_list

def performance_plot(start_date, end_date, on_datetime=True):
    plt.figure(figsize=(20, 15))
    # 未来一天的对数收益率，累计计算
    df_pnl = df_position.loc[start_date:end_date].copy()
    df_pnl['transaction'] = [df_pnl['position'].iloc[0]] + list(df_pnl['position'].diff().dropna().astype(int))
    df_pnl['period_log_ret'] = df_feature['log_ret'].rolling(predict_intervals).sum().loc[df_pnl.index]
    df_pnl['benchmark'] = trans_log([0] + list(df_pnl['period_log_ret'].iloc[1:].cumsum()))
    ret_array = df_pnl['period_log_ret'] * df_pnl['position'].shift()
    df_pnl['unrealized_pnl'] = trans_log(ret_array.cumsum())
    realized_pnl_list = [0]
    for i in df_pnl.index[1:]:
        if df_pnl.loc[i, 'transaction'] == -1:
            realized_pnl = df_pnl.loc[i, 'unrealized_pnl'] - FEE
        else:
            realized_pnl = realized_pnl_list[-1]
        realized_pnl_list.append(realized_pnl)

    df_pnl['realized_pnl'] = realized_pnl_list
    df_pnl.fillna(0, inplace=True)
    if on_datetime:
        time_index = df_pnl.index
        buy_points = df_pnl[df_pnl['transaction'] > 0]['benchmark']
        sell_points = df_pnl[df_pnl['transaction'] < 0]['benchmark']
        plt.scatter(buy_points.index, buy_points.values, color='red', s=20)
        plt.scatter(sell_points.index, sell_points.values, color='green', s=20)
    else:
        time_index = np.arange(len(df_pnl.index))
    plt.plot(time_index, df_pnl['benchmark'].values, label='benchmark')
    plt.plot(time_index, df_pnl['unrealized_pnl'].values, color='orange', label='unrealized')
    plt.plot(time_index, (1+df_pnl['unrealized_pnl'].values)/(1+df_pnl['benchmark'].values)-1, color='gray', label='excess')
    plt.plot(time_index, df_pnl['realized_pnl'].values, color='red', label='realized')
    plt.legend()
    plt.show()
    return df_pnl
df_pnl = performance_plot(df_position.index[0], df_position.index[-1])
performance_evaluation(df_pnl['realized_pnl'])
sharpe_ratio(df_pnl['realized_pnl'], frequency='30min')
# Out:
# 年化收益率： 0.0488
# 最大回撤： 0.0479
# 交易频率： 0.08
# 胜率： 0.3915
# 盈亏比： 1.78
# 0.34

# %% [markdown]
# 策略的波动率应该用unrealized还是realized

# %% [markdown]
# long short

# %%
def performance_plot(start_date, end_date, on_datetime=True):
    plt.figure(figsize=(20, 15))
    # 未来一天的对数收益率，累计计算
    df_pnl = df_position.loc[start_date:end_date].copy()
    df_pnl['transaction'] = [df_pnl['position'].iloc[0]] + list(df_pnl['position'].diff().dropna().astype(int))
    df_pnl['period_log_ret'] = df_feature['log_ret'].rolling(predict_intervals).sum().loc[df_pnl.index]
    df_pnl['benchmark'] = trans_log([0] + list(df_pnl['period_log_ret'].iloc[1:].cumsum()))
    ret_array = df_pnl['period_log_ret'] * df_pnl['position'].shift()
    df_pnl['unrealized_pnl'] = trans_log(ret_array.cumsum())
    df_pnl['realized_pnl'] = df_pnl['unrealized_pnl'] - FEE*abs(df_pnl['transaction']).cumsum()
    df_pnl.fillna(0, inplace=True)
    if on_datetime:
        time_index = df_pnl.index
        buy_points = df_pnl[df_pnl['transaction'] > 0]['benchmark']
        sell_points = df_pnl[df_pnl['transaction'] < 0]['benchmark']
        plt.scatter(buy_points.index, buy_points.values, color='red', s=20)
        plt.scatter(sell_points.index, sell_points.values, color='green', s=20)
    else:
        time_index = np.arange(len(df_pnl.index))
    plt.plot(time_index, df_pnl['benchmark'].values, label='benchmark')
    plt.plot(time_index, df_pnl['unrealized_pnl'].values, color='orange', label='unrealized')
    plt.plot(time_index, (1+df_pnl['unrealized_pnl'].values)/(1+df_pnl['benchmark'].values)-1, color='gray', label='excess')
    plt.plot(time_index, df_pnl['realized_pnl'].values, color='red', label='realized')
    plt.legend()
    plt.show()
    return df_pnl
# 仓位信息
position_list = []
position = 0
signal = 0
for i in df_predict.index[:-1]:
    # 计算信号
    if df_predict.loc[i, 'predict_label'] == 1:
        signal = 1
    elif df_predict.loc[i, 'predict_label'] == 0:
        signal = -1
    else:
        signal = 0
    
    # 计算仓位
    if position < 1 and signal == 1:
        position = 1
    elif position > -1 and signal == -1:
        position = -1
    
    position_list.append(position)
position_list.append(0)

df_position = df_predict.copy()
df_position['position'] = position_list
df_pnl = performance_plot(df_predict.index[0], df_predict.index[-1])
performance_evaluation(df_pnl['realized_pnl'])
sharpe_ratio(df_pnl['realized_pnl'], frequency='30min')
# Out:
# 年化收益率： 0.152
# 最大回撤： 0.1539
# 交易频率： 1.0
# 胜率： 0.5094
# 盈亏比： 1.01
# 0.61

# %% [markdown]
# 可以看出满仓做多空的交易成本是巨大的，需要降低策略的交易频率

# %% [markdown]
# 引入日度择时，设计一个日内回转策略

# %% [markdown]
# https://www.myquant.cn/docs/python_strategyies/108

# %% [markdown]
# 策略逻辑
#
# 日度策略看多建底仓，看空不建底仓
#
# 每日收盘前做仓位平衡
#
# 每天最多有8次日内交易
#
# 日内回转可能的情况有：（仓位数）
#
# -1 1 -1 1 -1 1 -1 0, 共交易了空7手，多7手，最多需要7个底仓
#
# 1 -1 1 -1 1 -1 1 0， 共交易了空7手，多7手，最多需要7个底仓
#
# 可以看出最大仓位数应该设置为7

# %%
df_daily_signal = pd.read_csv(data_path + '/daily_strategy/signals/000300_沪深300_vnsp_llt.csv', index_col=0)
df_daily_signal.columns = ['close', 'signal']
df_daily_signal['signal'] = df_daily_signal['signal'].astype(int)
df_daily_signal
# Out:
#               close  signal
# 2005-10-25   894.27       1
# 2005-10-26   875.82      -1
# 2005-10-27   875.85      -1
# 2005-10-28   867.73      -1
# 2005-10-31   876.28      -1
# ...             ...     ...
# 2023-05-09  4027.88      -1
# 2023-05-10  3996.87      -1
# 2023-05-11  3990.66      -1
# 2023-05-12  3937.76      -1
# 2023-05-15  3998.89      -1
#
# [4267 rows x 2 columns]

# %%
max_position = 7
df_daily_position = df_daily_signal.copy()
df_daily_position['position'] = np.where(df_daily_position['signal'] == 1, max_position, 0)
df_daily_position
# Out:
#               close  signal  position
# 2005-10-25   894.27       1         7
# 2005-10-26   875.82      -1         0
# 2005-10-27   875.85      -1         0
# 2005-10-28   867.73      -1         0
# 2005-10-31   876.28      -1         0
# ...             ...     ...       ...
# 2023-05-09  4027.88      -1         0
# 2023-05-10  3996.87      -1         0
# 2023-05-11  3990.66      -1         0
# 2023-05-12  3937.76      -1         0
# 2023-05-15  3998.89      -1         0
#
# [4267 rows x 3 columns]

# %% [markdown]
# 日度择时的performance

# %% [markdown]
# 上面是采取的对数收益率累加计算收益率
# 下面直接采取买卖价格算净值

# %% [markdown]
# 这里的年化收益率有点问题
#
# 可以看出log_return是在买卖一单位标的的情况下计算的，而且最后需要取指数
#
# 然而直接用价格计算是在买卖资金随交易的增长的情况下计算的
#
# 两者的差异需要得到关注！！！

# %% [markdown]
# 下面将收益率取指数

# %%
def performance_plot(start_date, end_date, on_datetime=True):
    plt.figure(figsize=(20, 15))
    # 未来一天的对数收益率，累计计算
    df_position = df_daily_position.copy()
    df_position.index = pd.to_datetime(df_position.index)
    df_pnl = df_position.loc[start_date:end_date].copy()
    position_values = df_pnl['position']/7
    df_pnl['position'] = position_values
    df_pnl['transaction'] = [df_pnl['position'].iloc[0]] + list(df_pnl['position'].diff().dropna().astype(int))
    df_pnl['period_log_ret'] = np.log(df_pnl['close']/df_pnl['close'].shift())
    df_pnl['benchmark'] = trans_log([0] + list(df_pnl['period_log_ret'].iloc[1:].cumsum()))
    ret_array = df_pnl['period_log_ret'] * df_pnl['position'].shift()
    df_pnl['unrealized_pnl'] = trans_log(ret_array.cumsum())
    realized_pnl_list = [0]
    for i in df_pnl.index[1:]:
        if df_pnl.loc[i, 'transaction'] == -1:
            realized_pnl = df_pnl.loc[i, 'unrealized_pnl'] - FEE
        else:
            realized_pnl = realized_pnl_list[-1]
        realized_pnl_list.append(realized_pnl)
    df_pnl['realized_pnl'] = realized_pnl_list
    df_pnl.fillna(0, inplace=True)
    if on_datetime:
        time_index = df_pnl.index
        buy_points = df_pnl[df_pnl['transaction'] > 0]['benchmark']
        sell_points = df_pnl[df_pnl['transaction'] < 0]['benchmark']
        plt.scatter(buy_points.index, buy_points.values, color='red', s=20)
        plt.scatter(sell_points.index, sell_points.values, color='green', s=20)
    else:
        time_index = np.arange(len(df_pnl.index))
    plt.plot(time_index, df_pnl['benchmark'].values, label='benchmark')
    plt.plot(time_index, df_pnl['unrealized_pnl'].values, color='orange', label='unrealized')
    plt.plot(time_index, (1+df_pnl['unrealized_pnl'].values)/(1+df_pnl['benchmark'].values)-1, color='gray', label='excess')
    plt.plot(time_index, df_pnl['realized_pnl'].values, color='red', label='realized')
    plt.legend()
    plt.show()
    return df_pnl
df_pnl = performance_plot('2005', '2022-06')
performance_evaluation(df_pnl['realized_pnl'])
sharpe_ratio(df_pnl['realized_pnl'], frequency='day')
# Out:
# 年化收益率： 0.1575
# 最大回撤： 0.2551
# 交易频率： 0.03
# 胜率： 0.5662
# 盈亏比： 1.68
# 0.14

# %%
def performance_plot(start_date, end_date, on_datetime=True):
    plt.figure(figsize=(20, 15))
    # 未来一天的对数收益率，累计计算
    df_pnl = df_position.loc[start_date:end_date].copy()
    df_pnl['transaction'] = [df_pnl['position'].iloc[0]] + list(df_pnl['position'].diff().dropna().astype(int))
    df_pnl['period_log_ret'] = df_feature['log_ret'].rolling(predict_intervals).sum().loc[df_pnl.index]
    df_pnl['benchmark'] = trans_log([0] + list(df_pnl['period_log_ret'].iloc[1:].cumsum()))
    ret_array = df_pnl['period_log_ret'] * df_pnl['position'].shift()
    df_pnl['unrealized_pnl'] = trans_log(ret_array.cumsum())
    df_pnl['realized_pnl'] = df_pnl['unrealized_pnl'] - FEE*abs(df_pnl['transaction']).cumsum()
    df_pnl.fillna(0, inplace=True)
    if on_datetime:
        time_index = df_pnl.index
        buy_points = df_pnl[df_pnl['transaction'] > 0]['benchmark']
        sell_points = df_pnl[df_pnl['transaction'] < 0]['benchmark']
        plt.scatter(buy_points.index, buy_points.values, color='red', s=20)
        plt.scatter(sell_points.index, sell_points.values, color='green', s=20)
    else:
        time_index = np.arange(len(df_pnl.index))
    plt.plot(time_index, df_pnl['benchmark'].values, label='benchmark')
    plt.plot(time_index, df_pnl['unrealized_pnl'].values, color='orange', label='unrealized')
    plt.plot(time_index, (1+df_pnl['unrealized_pnl'].values)/(1+df_pnl['benchmark'].values)-1, color='gray', label='excess')
    plt.plot(time_index, df_pnl['realized_pnl'].values, color='red', label='realized')
    plt.legend()
    plt.show()
    return df_pnl
# 仓位信息
position_list = []
position = 0
signal = 0
for i in range(len(df_predict.index[:-1])):
    trade_time = df_predict.index[i]
    date = trade_time.strftime('%Y-%m-%d')
    last_daily_position = df_daily_position.loc[:date, 'position'].iloc[-2]
    
    if df_predict.index[i+1].strftime('%Y-%m-%d') != date:
        position = 0 # 收盘前仓位平衡
    else:
        # 计算信号
        if df_predict.loc[trade_time, 'predict_label'] == 1:
            signal = 1
        elif df_predict.loc[trade_time, 'predict_label'] == 0:
            signal = -1
        else:
            signal = 0
        
        # 计算仓位
        if last_daily_position > 0:
            # 有底仓的基础上，日内回转（多空）
            if position < 1 and signal == 1:
                position = 1
            elif position > -1 and signal == -1:
                position = -1
        else:
            position = 0
        
    position_list.append(position)

position_list.append(0)

df_position = df_predict.copy()
df_position['position'] = position_list
df_position['transaction'] = [position_list[0]] + list(df_position['position'].diff().dropna().astype(int))
df_pnl = performance_plot(df_predict.index[0], df_predict.index[-1])
performance_evaluation(df_pnl['realized_pnl'])
sharpe_ratio(df_pnl['realized_pnl'], frequency='30min')
# Out:
# 年化收益率： -0.143
# 最大回撤： 0.2162
# 交易频率： 0.43
# 胜率： 0.4268
# 盈亏比： 1.15
# -1.81

# %% [markdown]
# 可以看出：
#
# 1. 日度择时做底仓的基础上进行日内回转的效果并不好
#
#     解决方法：引入其他ETF，做横截面的策略，然后再进行日内回转
#
# 2. 日内回转吃的是波动率而不是日度择时下的价格上涨
#
#     相反地，价格上涨反而会降低波动率，检验一下
#
#     如果是这样的话，那么引入波动率预测模型，只在波动率上升时日内回转
#
# 3. 尝试在日度择时下的价格上涨只做顺T
#
# 总结：
#
# 先在时序模型上引入日度波动率预测，然后引入横截面策略

# %% [markdown]
# 防止过拟合也可以随机选取起止日期，看回测曲线与策略评价指标（时间敏感性）——幸存者偏差
